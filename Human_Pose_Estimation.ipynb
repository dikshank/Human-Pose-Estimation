# %% [markdown]
# <a href="https://colab.research.google.com/github/dikshank/Human-Pose-Estimation/blob/main/Human_Pose_Estimation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import json
import matplotlib.pyplot as plt
import cv2
from PIL import UnidentifiedImageError
from scipy.ndimage import gaussian_filter
from PIL import Image
import os
from keras.layers import Conv2D,Conv2DTranspose,BatchNormalization,Dropout
from keras.applications import resnet_v2
from keras.models import Model, Sequential
from keras.layers import Input
from keras.layers import ReLU
from keras.layers import Reshape
from keras.initializers import random_normal
import tensorflow as tf
import keras

# %% [markdown]
# # downloading the dataset

# %%
# ! wget http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Out:
# --2022-01-30 01:22:30--  http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.217.201.145
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.217.201.145|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 252907541 (241M) [application/zip]
# Saving to: ‘annotations_trainval2017.zip’
#
# annotations_trainva 100%[===================>] 241.19M  50.4MB/s    in 4.9s
#
# 2022-01-30 01:22:35 (48.7 MB/s) - ‘annotations_trainval2017.zip’ saved [252907541/252907541]

# %%
# ! mkdir 'Human Pose Estimation Data'

# %%
# ls

# %%
# cd /content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data
# Out:
# /content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data

# %%
# ! unzip /content/drive/MyDrive/'Human Pose Estimation'/annotations_trainval2017.zip
# Out:
# Archive:  /content/drive/MyDrive/Human Pose Estimation/annotations_trainval2017.zip
#   inflating: annotations/instances_train2017.json
#   inflating: annotations/instances_val2017.json
#   inflating: annotations/captions_train2017.json
#   inflating: annotations/captions_val2017.json
#   inflating: annotations/person_keypoints_train2017.json
#   inflating: annotations/person_keypoints_val2017.json

# %%
jason_annotations_path = '/content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data/annotations/person_keypoints_train2017.json'

# %%
file_handle = open(jason_annotations_path)

# %%
file_handle
# Out:
# <_io.TextIOWrapper name='/content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data/annotations/person_keypoints_train2017.json' mode='r' encoding='UTF-8'>

# %%
jason_annotations = json.load(file_handle)  #this is a dictionary data and each key of this dictionary contains list of information for every image

# %%
# jason_annotations['annotations']

# %%
# jason_annotations['images']

# %%
# jason_annotations["annotations"][0]["keypoints"]

# %%
def compile_examples(json_annotations):

  file_handle = open(json_annotations)
  annotations = json.load(file_handle)

  image_urls = list()

  for image_detail in annotations["images"]:
    image_urls.append(image_detail["coco_url"])

  image_ids = list()

  for single_annotation in annotations["annotations"]:
    image_ids.append(single_annotation["image_id"])

  urls_dict = dict()  # this will contain an image name as key and its url as the value

  for img_url in image_urls:
    urls_dict[img_url.split("/")[-1]] = img_url

  image_details = dict()
  images_added = list()
  url_for_downloads = []
  for single_annotation in annotations["annotations"]:

    img_filename = "000000"+str(single_annotation["image_id"])+".jpg"

    keypoints = np.array(single_annotation["keypoints"]).reshape(17,3)
    gt_validity = keypoints[:,2] > 0

    if img_filename in list(urls_dict.keys()) and sum(gt_validity) > 0 and single_annotation["iscrowd"] == 0 and single_annotation["bbox"][2] > 48 and single_annotation["bbox"][3] > 64:

      images_added.append(img_filename)
      image_details[img_filename] = dict()
      image_details[img_filename]["url"] = urls_dict[img_filename]
      image_details[img_filename]["num_keypoints"] = single_annotation["num_keypoints"]
      image_details[img_filename]["bbox"] = single_annotation["bbox"]
      image_details[img_filename]["keypoints"] = single_annotation["keypoints"]
      url_for_downloads.append(urls_dict[img_filename])
  return image_details, url_for_downloads

# %%
# training_annotations, training_urls = compile_examples('/content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data/annotations/person_keypoints_train2017.json')

# %%
# cv_annotations, cv_urls = compile_examples("/content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data/annotations/person_keypoints_val2017.json")

# %%
# training_annotations

# %%
pwd
# Out:
# '/content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data'

# %%
# ! mkdir 'person train images' 'person cv images'

# %%
ls
# Out:
#  annotations/         'person cv images'/
#  cv_annotations.json  'person train images'/

# %%
# training_images_list = (training_annotations.keys())

# %%
# training_images_urls = []
# for imgs in training_images_list:
#   training_images_urls.append(training_annotations[imgs]['url'])

# %%
# cv_images_list = (cv_annotations.keys())

# %%
# cv_images_urls = []
# for imgs in cv_images_list:
#   cv_images_urls.append(cv_annotations[imgs]['url'])

# %%
len(cv_images_urls)
# Out:
# 1788

# %% [markdown]
# downloading training images

# %%
cd /content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data
# Out:
# /content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data

# %%
! echo train_url_file.txt
# Out:
# train_url_file.txt

# %%
# with open("train_url_file.txt", 'w') as file:
#   for row in training_images_urls:
#       s = "".join(map(str, row))
#       file.write(s+'\n')

# %%
ls
# Out:
#  annotations/         'person cv images'/      train_url_file.txt
#  cv_annotations.json  'person train images'/   train_url.txt

# %%
cd /content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data/person train images
# Out:
# /content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data/person train images

# %%
# ! wget -i /content/drive/MyDrive/'Human Pose Estimation'/'Human Pose Estimation Data'/train_url_file.txt
# Out:
# Streaming output truncated to the last 5000 lines.
# Length: 141392 (138K) [image/jpeg]
# Saving to: ‘000000402287.jpg’
#
# 000000402287.jpg    100%[===================>] 138.08K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:24:55 (34.9 MB/s) - ‘000000402287.jpg’ saved [141392/141392]
#
# --2022-01-30 05:24:55--  http://images.cocodataset.org/train2017/000000263823.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 18561 (18K) [image/jpeg]
# Saving to: ‘000000263823.jpg’
#
# 000000263823.jpg    100%[===================>]  18.13K  --.-KB/s    in 0.001s
#
# 2022-01-30 05:24:55 (19.7 MB/s) - ‘000000263823.jpg’ saved [18561/18561]
#
# --2022-01-30 05:24:55--  http://images.cocodataset.org/train2017/000000379188.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 81043 (79K) [image/jpeg]
# Saving to: ‘000000379188.jpg’
#
# 000000379188.jpg    100%[===================>]  79.14K  --.-KB/s    in 0.009s
#
# 2022-01-30 05:24:55 (8.42 MB/s) - ‘000000379188.jpg’ saved [81043/81043]
#
# --2022-01-30 05:24:55--  http://images.cocodataset.org/train2017/000000117987.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 203066 (198K) [image/jpeg]
# Saving to: ‘000000117987.jpg’
#
# 000000117987.jpg    100%[===================>] 198.31K  --.-KB/s    in 0.009s
#
# 2022-01-30 05:24:55 (22.4 MB/s) - ‘000000117987.jpg’ saved [203066/203066]
#
# --2022-01-30 05:24:55--  http://images.cocodataset.org/train2017/000000238615.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 129070 (126K) [image/jpeg]
# Saving to: ‘000000238615.jpg’
#
# 000000238615.jpg    100%[===================>] 126.04K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:24:56 (30.1 MB/s) - ‘000000238615.jpg’ saved [129070/129070]
#
# --2022-01-30 05:24:56--  http://images.cocodataset.org/train2017/000000159554.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 126687 (124K) [image/jpeg]
# Saving to: ‘000000159554.jpg’
#
# 000000159554.jpg    100%[===================>] 123.72K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:24:56 (63.3 MB/s) - ‘000000159554.jpg’ saved [126687/126687]
#
# --2022-01-30 05:24:56--  http://images.cocodataset.org/train2017/000000395958.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 207162 (202K) [image/jpeg]
# Saving to: ‘000000395958.jpg’
#
# 000000395958.jpg    100%[===================>] 202.31K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:24:56 (73.0 MB/s) - ‘000000395958.jpg’ saved [207162/207162]
#
# --2022-01-30 05:24:56--  http://images.cocodataset.org/train2017/000000468382.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 303780 (297K) [image/jpeg]
# Saving to: ‘000000468382.jpg’
#
# 000000468382.jpg    100%[===================>] 296.66K  --.-KB/s    in 0.005s
#
# 2022-01-30 05:24:56 (62.3 MB/s) - ‘000000468382.jpg’ saved [303780/303780]
#
# --2022-01-30 05:24:56--  http://images.cocodataset.org/train2017/000000440783.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 292222 (285K) [image/jpeg]
# Saving to: ‘000000440783.jpg’
#
# 000000440783.jpg    100%[===================>] 285.37K  --.-KB/s    in 0.005s
#
# 2022-01-30 05:24:56 (54.5 MB/s) - ‘000000440783.jpg’ saved [292222/292222]
#
# --2022-01-30 05:24:56--  http://images.cocodataset.org/train2017/000000477860.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 256682 (251K) [image/jpeg]
# Saving to: ‘000000477860.jpg’
#
# 000000477860.jpg    100%[===================>] 250.67K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:24:56 (57.3 MB/s) - ‘000000477860.jpg’ saved [256682/256682]
#
# --2022-01-30 05:24:56--  http://images.cocodataset.org/train2017/000000204664.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 144236 (141K) [image/jpeg]
# Saving to: ‘000000204664.jpg’
#
# 000000204664.jpg    100%[===================>] 140.86K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:24:56 (39.0 MB/s) - ‘000000204664.jpg’ saved [144236/144236]
#
# --2022-01-30 05:24:56--  http://images.cocodataset.org/train2017/000000284863.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 122307 (119K) [image/jpeg]
# Saving to: ‘000000284863.jpg’
#
# 000000284863.jpg    100%[===================>] 119.44K  --.-KB/s    in 0.02s
#
# 2022-01-30 05:24:56 (5.32 MB/s) - ‘000000284863.jpg’ saved [122307/122307]
#
# --2022-01-30 05:24:56--  http://images.cocodataset.org/train2017/000000106657.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 155040 (151K) [image/jpeg]
# Saving to: ‘000000106657.jpg’
#
# 000000106657.jpg    100%[===================>] 151.41K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:24:56 (45.7 MB/s) - ‘000000106657.jpg’ saved [155040/155040]
#
# --2022-01-30 05:24:56--  http://images.cocodataset.org/train2017/000000234016.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 193035 (189K) [image/jpeg]
# Saving to: ‘000000234016.jpg’
#
# 000000234016.jpg    100%[===================>] 188.51K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:24:57 (55.4 MB/s) - ‘000000234016.jpg’ saved [193035/193035]
#
# --2022-01-30 05:24:57--  http://images.cocodataset.org/train2017/000000159971.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 215134 (210K) [image/jpeg]
# Saving to: ‘000000159971.jpg’
#
# 000000159971.jpg    100%[===================>] 210.09K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:24:57 (73.4 MB/s) - ‘000000159971.jpg’ saved [215134/215134]
#
# --2022-01-30 05:24:57--  http://images.cocodataset.org/train2017/000000579594.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 145009 (142K) [image/jpeg]
# Saving to: ‘000000579594.jpg’
#
# 000000579594.jpg    100%[===================>] 141.61K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:24:57 (33.4 MB/s) - ‘000000579594.jpg’ saved [145009/145009]
#
# --2022-01-30 05:24:57--  http://images.cocodataset.org/train2017/000000491229.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 226817 (222K) [image/jpeg]
# Saving to: ‘000000491229.jpg’
#
# 000000491229.jpg    100%[===================>] 221.50K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:24:57 (54.9 MB/s) - ‘000000491229.jpg’ saved [226817/226817]
#
# --2022-01-30 05:24:57--  http://images.cocodataset.org/train2017/000000356182.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 68123 (67K) [image/jpeg]
# Saving to: ‘000000356182.jpg’
#
# 000000356182.jpg    100%[===================>]  66.53K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:24:57 (23.2 MB/s) - ‘000000356182.jpg’ saved [68123/68123]
#
# --2022-01-30 05:24:57--  http://images.cocodataset.org/train2017/000000470308.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 134106 (131K) [image/jpeg]
# Saving to: ‘000000470308.jpg’
#
# 000000470308.jpg    100%[===================>] 130.96K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:24:57 (56.3 MB/s) - ‘000000470308.jpg’ saved [134106/134106]
#
# --2022-01-30 05:24:57--  http://images.cocodataset.org/train2017/000000495356.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 83638 (82K) [image/jpeg]
# Saving to: ‘000000495356.jpg’
#
# 000000495356.jpg    100%[===================>]  81.68K  --.-KB/s    in 0.007s
#
# 2022-01-30 05:24:57 (10.7 MB/s) - ‘000000495356.jpg’ saved [83638/83638]
#
# --2022-01-30 05:24:57--  http://images.cocodataset.org/train2017/000000271500.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 93737 (92K) [image/jpeg]
# Saving to: ‘000000271500.jpg’
#
# 000000271500.jpg    100%[===================>]  91.54K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:24:57 (57.5 MB/s) - ‘000000271500.jpg’ saved [93737/93737]
#
# --2022-01-30 05:24:57--  http://images.cocodataset.org/train2017/000000125036.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 173818 (170K) [image/jpeg]
# Saving to: ‘000000125036.jpg’
#
# 000000125036.jpg    100%[===================>] 169.74K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:24:57 (40.3 MB/s) - ‘000000125036.jpg’ saved [173818/173818]
#
# --2022-01-30 05:24:57--  http://images.cocodataset.org/train2017/000000502043.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 112185 (110K) [image/jpeg]
# Saving to: ‘000000502043.jpg’
#
# 000000502043.jpg    100%[===================>] 109.56K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:24:57 (34.8 MB/s) - ‘000000502043.jpg’ saved [112185/112185]
#
# --2022-01-30 05:24:57--  http://images.cocodataset.org/train2017/000000423016.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 161473 (158K) [image/jpeg]
# Saving to: ‘000000423016.jpg’
#
# 000000423016.jpg    100%[===================>] 157.69K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:24:58 (42.9 MB/s) - ‘000000423016.jpg’ saved [161473/161473]
#
# --2022-01-30 05:24:58--  http://images.cocodataset.org/train2017/000000159465.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 199648 (195K) [image/jpeg]
# Saving to: ‘000000159465.jpg’
#
# 000000159465.jpg    100%[===================>] 194.97K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:24:58 (52.3 MB/s) - ‘000000159465.jpg’ saved [199648/199648]
#
# --2022-01-30 05:24:58--  http://images.cocodataset.org/train2017/000000483048.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 111398 (109K) [image/jpeg]
# Saving to: ‘000000483048.jpg’
#
# 000000483048.jpg    100%[===================>] 108.79K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:24:58 (35.3 MB/s) - ‘000000483048.jpg’ saved [111398/111398]
#
# --2022-01-30 05:24:58--  http://images.cocodataset.org/train2017/000000166163.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 137662 (134K) [image/jpeg]
# Saving to: ‘000000166163.jpg’
#
# 000000166163.jpg    100%[===================>] 134.44K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:24:58 (40.6 MB/s) - ‘000000166163.jpg’ saved [137662/137662]
#
# --2022-01-30 05:24:58--  http://images.cocodataset.org/train2017/000000435841.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 223434 (218K) [image/jpeg]
# Saving to: ‘000000435841.jpg’
#
# 000000435841.jpg    100%[===================>] 218.20K  --.-KB/s    in 0.005s
#
# 2022-01-30 05:24:58 (43.7 MB/s) - ‘000000435841.jpg’ saved [223434/223434]
#
# --2022-01-30 05:24:58--  http://images.cocodataset.org/train2017/000000191073.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 101152 (99K) [image/jpeg]
# Saving to: ‘000000191073.jpg’
#
# 000000191073.jpg    100%[===================>]  98.78K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:24:58 (56.8 MB/s) - ‘000000191073.jpg’ saved [101152/101152]
#
# --2022-01-30 05:24:58--  http://images.cocodataset.org/train2017/000000206349.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 64181 (63K) [image/jpeg]
# Saving to: ‘000000206349.jpg’
#
# 000000206349.jpg    100%[===================>]  62.68K  --.-KB/s    in 0.001s
#
# 2022-01-30 05:24:58 (47.1 MB/s) - ‘000000206349.jpg’ saved [64181/64181]
#
# --2022-01-30 05:24:58--  http://images.cocodataset.org/train2017/000000542928.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 111944 (109K) [image/jpeg]
# Saving to: ‘000000542928.jpg’
#
# 000000542928.jpg    100%[===================>] 109.32K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:24:58 (34.0 MB/s) - ‘000000542928.jpg’ saved [111944/111944]
#
# --2022-01-30 05:24:58--  http://images.cocodataset.org/train2017/000000122216.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 177149 (173K) [image/jpeg]
# Saving to: ‘000000122216.jpg’
#
# 000000122216.jpg    100%[===================>] 173.00K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:24:58 (73.5 MB/s) - ‘000000122216.jpg’ saved [177149/177149]
#
# --2022-01-30 05:24:58--  http://images.cocodataset.org/train2017/000000436809.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 75776 (74K) [image/jpeg]
# Saving to: ‘000000436809.jpg’
#
# 000000436809.jpg    100%[===================>]  74.00K  --.-KB/s    in 0.001s
#
# 2022-01-30 05:24:59 (53.3 MB/s) - ‘000000436809.jpg’ saved [75776/75776]
#
# --2022-01-30 05:24:59--  http://images.cocodataset.org/train2017/000000341695.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 160115 (156K) [image/jpeg]
# Saving to: ‘000000341695.jpg’
#
# 000000341695.jpg    100%[===================>] 156.36K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:24:59 (69.2 MB/s) - ‘000000341695.jpg’ saved [160115/160115]
#
# --2022-01-30 05:24:59--  http://images.cocodataset.org/train2017/000000508878.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 114625 (112K) [image/jpeg]
# Saving to: ‘000000508878.jpg’
#
# 000000508878.jpg    100%[===================>] 111.94K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:24:59 (26.0 MB/s) - ‘000000508878.jpg’ saved [114625/114625]
#
# --2022-01-30 05:24:59--  http://images.cocodataset.org/train2017/000000136922.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 186263 (182K) [image/jpeg]
# Saving to: ‘000000136922.jpg’
#
# 000000136922.jpg    100%[===================>] 181.90K  --.-KB/s    in 0.01s
#
# 2022-01-30 05:24:59 (12.6 MB/s) - ‘000000136922.jpg’ saved [186263/186263]
#
# --2022-01-30 05:24:59--  http://images.cocodataset.org/train2017/000000345225.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 202725 (198K) [image/jpeg]
# Saving to: ‘000000345225.jpg’
#
# 000000345225.jpg    100%[===================>] 197.97K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:24:59 (50.5 MB/s) - ‘000000345225.jpg’ saved [202725/202725]
#
# --2022-01-30 05:24:59--  http://images.cocodataset.org/train2017/000000455791.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 148381 (145K) [image/jpeg]
# Saving to: ‘000000455791.jpg’
#
# 000000455791.jpg    100%[===================>] 144.90K  --.-KB/s    in 0.03s
#
# 2022-01-30 05:24:59 (5.01 MB/s) - ‘000000455791.jpg’ saved [148381/148381]
#
# --2022-01-30 05:24:59--  http://images.cocodataset.org/train2017/000000325569.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 173626 (170K) [image/jpeg]
# Saving to: ‘000000325569.jpg’
#
# 000000325569.jpg    100%[===================>] 169.56K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:24:59 (52.0 MB/s) - ‘000000325569.jpg’ saved [173626/173626]
#
# --2022-01-30 05:24:59--  http://images.cocodataset.org/train2017/000000575535.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 161494 (158K) [image/jpeg]
# Saving to: ‘000000575535.jpg’
#
# 000000575535.jpg    100%[===================>] 157.71K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:24:59 (45.3 MB/s) - ‘000000575535.jpg’ saved [161494/161494]
#
# --2022-01-30 05:24:59--  http://images.cocodataset.org/train2017/000000281207.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 89017 (87K) [image/jpeg]
# Saving to: ‘000000281207.jpg’
#
# 000000281207.jpg    100%[===================>]  86.93K  --.-KB/s    in 0.001s
#
# 2022-01-30 05:24:59 (59.4 MB/s) - ‘000000281207.jpg’ saved [89017/89017]
#
# --2022-01-30 05:24:59--  http://images.cocodataset.org/train2017/000000514674.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 94183 (92K) [image/jpeg]
# Saving to: ‘000000514674.jpg’
#
# 000000514674.jpg    100%[===================>]  91.98K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:00 (30.0 MB/s) - ‘000000514674.jpg’ saved [94183/94183]
#
# --2022-01-30 05:25:00--  http://images.cocodataset.org/train2017/000000268909.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 305372 (298K) [image/jpeg]
# Saving to: ‘000000268909.jpg’
#
# 000000268909.jpg    100%[===================>] 298.21K  --.-KB/s    in 0.01s
#
# 2022-01-30 05:25:00 (25.1 MB/s) - ‘000000268909.jpg’ saved [305372/305372]
#
# --2022-01-30 05:25:00--  http://images.cocodataset.org/train2017/000000167184.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 239079 (233K) [image/jpeg]
# Saving to: ‘000000167184.jpg’
#
# 000000167184.jpg    100%[===================>] 233.48K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:00 (78.7 MB/s) - ‘000000167184.jpg’ saved [239079/239079]
#
# --2022-01-30 05:25:00--  http://images.cocodataset.org/train2017/000000421733.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 151709 (148K) [image/jpeg]
# Saving to: ‘000000421733.jpg’
#
# 000000421733.jpg    100%[===================>] 148.15K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:00 (76.2 MB/s) - ‘000000421733.jpg’ saved [151709/151709]
#
# --2022-01-30 05:25:00--  http://images.cocodataset.org/train2017/000000154710.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 158798 (155K) [image/jpeg]
# Saving to: ‘000000154710.jpg’
#
# 000000154710.jpg    100%[===================>] 155.08K  --.-KB/s    in 0.01s
#
# 2022-01-30 05:25:00 (14.2 MB/s) - ‘000000154710.jpg’ saved [158798/158798]
#
# --2022-01-30 05:25:00--  http://images.cocodataset.org/train2017/000000444397.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 188307 (184K) [image/jpeg]
# Saving to: ‘000000444397.jpg’
#
# 000000444397.jpg    100%[===================>] 183.89K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:00 (65.6 MB/s) - ‘000000444397.jpg’ saved [188307/188307]
#
# --2022-01-30 05:25:00--  http://images.cocodataset.org/train2017/000000190938.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 39256 (38K) [image/jpeg]
# Saving to: ‘000000190938.jpg’
#
# 000000190938.jpg    100%[===================>]  38.34K  --.-KB/s    in 0.001s
#
# 2022-01-30 05:25:00 (33.1 MB/s) - ‘000000190938.jpg’ saved [39256/39256]
#
# --2022-01-30 05:25:00--  http://images.cocodataset.org/train2017/000000433217.jpg
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.217.76.228|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 156733 (153K) [image/jpeg]
# Saving to: ‘000000433217.jpg’
#
# 000000433217.jpg    100%[===================>] 153.06K  --.-KB/s    in 0.09s
#
# 2022-01-30 05:25:00 (1.73 MB/s) - ‘000000433217.jpg’ saved [156733/156733]
#
# --2022-01-30 05:25:00--  http://images.cocodataset.org/train2017/000000229680.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 152500 (149K) [image/jpeg]
# Saving to: ‘000000229680.jpg’
#
# 000000229680.jpg    100%[===================>] 148.93K  --.-KB/s    in 0.03s
#
# 2022-01-30 05:25:01 (5.23 MB/s) - ‘000000229680.jpg’ saved [152500/152500]
#
# --2022-01-30 05:25:01--  http://images.cocodataset.org/train2017/000000537424.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 201151 (196K) [image/jpeg]
# Saving to: ‘000000537424.jpg’
#
# 000000537424.jpg    100%[===================>] 196.44K  --.-KB/s    in 0.02s
#
# 2022-01-30 05:25:01 (9.70 MB/s) - ‘000000537424.jpg’ saved [201151/201151]
#
# --2022-01-30 05:25:01--  http://images.cocodataset.org/train2017/000000224695.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 159996 (156K) [image/jpeg]
# Saving to: ‘000000224695.jpg’
#
# 000000224695.jpg    100%[===================>] 156.25K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:01 (52.4 MB/s) - ‘000000224695.jpg’ saved [159996/159996]
#
# --2022-01-30 05:25:01--  http://images.cocodataset.org/train2017/000000141013.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 227081 (222K) [image/jpeg]
# Saving to: ‘000000141013.jpg’
#
# 000000141013.jpg    100%[===================>] 221.76K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:25:01 (51.7 MB/s) - ‘000000141013.jpg’ saved [227081/227081]
#
# --2022-01-30 05:25:01--  http://images.cocodataset.org/train2017/000000510209.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 215664 (211K) [image/jpeg]
# Saving to: ‘000000510209.jpg’
#
# 000000510209.jpg    100%[===================>] 210.61K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:25:01 (46.4 MB/s) - ‘000000510209.jpg’ saved [215664/215664]
#
# --2022-01-30 05:25:01--  http://images.cocodataset.org/train2017/000000320117.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 164419 (161K) [image/jpeg]
# Saving to: ‘000000320117.jpg’
#
# 000000320117.jpg    100%[===================>] 160.57K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:01 (56.1 MB/s) - ‘000000320117.jpg’ saved [164419/164419]
#
# --2022-01-30 05:25:01--  http://images.cocodataset.org/train2017/000000434409.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 112856 (110K) [image/jpeg]
# Saving to: ‘000000434409.jpg’
#
# 000000434409.jpg    100%[===================>] 110.21K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:01 (31.8 MB/s) - ‘000000434409.jpg’ saved [112856/112856]
#
# --2022-01-30 05:25:01--  http://images.cocodataset.org/train2017/000000207496.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 74431 (73K) [image/jpeg]
# Saving to: ‘000000207496.jpg’
#
# 000000207496.jpg    100%[===================>]  72.69K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:01 (25.3 MB/s) - ‘000000207496.jpg’ saved [74431/74431]
#
# --2022-01-30 05:25:01--  http://images.cocodataset.org/train2017/000000204378.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 113394 (111K) [image/jpeg]
# Saving to: ‘000000204378.jpg’
#
# 000000204378.jpg    100%[===================>] 110.74K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:02 (60.4 MB/s) - ‘000000204378.jpg’ saved [113394/113394]
#
# --2022-01-30 05:25:02--  http://images.cocodataset.org/train2017/000000197063.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 154822 (151K) [image/jpeg]
# Saving to: ‘000000197063.jpg’
#
# 000000197063.jpg    100%[===================>] 151.19K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:02 (77.4 MB/s) - ‘000000197063.jpg’ saved [154822/154822]
#
# --2022-01-30 05:25:02--  http://images.cocodataset.org/train2017/000000184493.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 162376 (159K) [image/jpeg]
# Saving to: ‘000000184493.jpg’
#
# 000000184493.jpg    100%[===================>] 158.57K  --.-KB/s    in 0.006s
#
# 2022-01-30 05:25:02 (27.9 MB/s) - ‘000000184493.jpg’ saved [162376/162376]
#
# --2022-01-30 05:25:02--  http://images.cocodataset.org/train2017/000000168779.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 192231 (188K) [image/jpeg]
# Saving to: ‘000000168779.jpg’
#
# 000000168779.jpg    100%[===================>] 187.73K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:25:02 (47.9 MB/s) - ‘000000168779.jpg’ saved [192231/192231]
#
# --2022-01-30 05:25:02--  http://images.cocodataset.org/train2017/000000267753.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 111407 (109K) [image/jpeg]
# Saving to: ‘000000267753.jpg’
#
# 000000267753.jpg    100%[===================>] 108.80K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:02 (36.9 MB/s) - ‘000000267753.jpg’ saved [111407/111407]
#
# --2022-01-30 05:25:02--  http://images.cocodataset.org/train2017/000000536425.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 110684 (108K) [image/jpeg]
# Saving to: ‘000000536425.jpg’
#
# 000000536425.jpg    100%[===================>] 108.09K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:02 (37.2 MB/s) - ‘000000536425.jpg’ saved [110684/110684]
#
# --2022-01-30 05:25:02--  http://images.cocodataset.org/train2017/000000535464.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 128550 (126K) [image/jpeg]
# Saving to: ‘000000535464.jpg’
#
# 000000535464.jpg    100%[===================>] 125.54K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:02 (43.6 MB/s) - ‘000000535464.jpg’ saved [128550/128550]
#
# --2022-01-30 05:25:02--  http://images.cocodataset.org/train2017/000000570085.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 129020 (126K) [image/jpeg]
# Saving to: ‘000000570085.jpg’
#
# 000000570085.jpg    100%[===================>] 126.00K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:02 (39.6 MB/s) - ‘000000570085.jpg’ saved [129020/129020]
#
# --2022-01-30 05:25:02--  http://images.cocodataset.org/train2017/000000129278.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 169342 (165K) [image/jpeg]
# Saving to: ‘000000129278.jpg’
#
# 000000129278.jpg    100%[===================>] 165.37K  --.-KB/s    in 0.02s
#
# 2022-01-30 05:25:02 (10.8 MB/s) - ‘000000129278.jpg’ saved [169342/169342]
#
# --2022-01-30 05:25:02--  http://images.cocodataset.org/train2017/000000184589.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 234398 (229K) [image/jpeg]
# Saving to: ‘000000184589.jpg’
#
# 000000184589.jpg    100%[===================>] 228.90K  --.-KB/s    in 0.005s
#
# 2022-01-30 05:25:03 (49.3 MB/s) - ‘000000184589.jpg’ saved [234398/234398]
#
# --2022-01-30 05:25:03--  http://images.cocodataset.org/train2017/000000138772.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 167471 (164K) [image/jpeg]
# Saving to: ‘000000138772.jpg’
#
# 000000138772.jpg    100%[===================>] 163.55K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:03 (77.9 MB/s) - ‘000000138772.jpg’ saved [167471/167471]
#
# --2022-01-30 05:25:03--  http://images.cocodataset.org/train2017/000000377488.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 46258 (45K) [image/jpeg]
# Saving to: ‘000000377488.jpg’
#
# 000000377488.jpg    100%[===================>]  45.17K  --.-KB/s    in 0.001s
#
# 2022-01-30 05:25:03 (41.4 MB/s) - ‘000000377488.jpg’ saved [46258/46258]
#
# --2022-01-30 05:25:03--  http://images.cocodataset.org/train2017/000000320467.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 72805 (71K) [image/jpeg]
# Saving to: ‘000000320467.jpg’
#
# 000000320467.jpg    100%[===================>]  71.10K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:03 (34.8 MB/s) - ‘000000320467.jpg’ saved [72805/72805]
#
# --2022-01-30 05:25:03--  http://images.cocodataset.org/train2017/000000455902.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 133158 (130K) [image/jpeg]
# Saving to: ‘000000455902.jpg’
#
# 000000455902.jpg    100%[===================>] 130.04K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:03 (67.7 MB/s) - ‘000000455902.jpg’ saved [133158/133158]
#
# --2022-01-30 05:25:03--  http://images.cocodataset.org/train2017/000000345855.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 81338 (79K) [image/jpeg]
# Saving to: ‘000000345855.jpg’
#
# 000000345855.jpg    100%[===================>]  79.43K  --.-KB/s    in 0.001s
#
# 2022-01-30 05:25:03 (58.4 MB/s) - ‘000000345855.jpg’ saved [81338/81338]
#
# --2022-01-30 05:25:03--  http://images.cocodataset.org/train2017/000000453037.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 232946 (227K) [image/jpeg]
# Saving to: ‘000000453037.jpg’
#
# 000000453037.jpg    100%[===================>] 227.49K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:25:03 (54.4 MB/s) - ‘000000453037.jpg’ saved [232946/232946]
#
# --2022-01-30 05:25:03--  http://images.cocodataset.org/train2017/000000575628.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 144561 (141K) [image/jpeg]
# Saving to: ‘000000575628.jpg’
#
# 000000575628.jpg    100%[===================>] 141.17K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:03 (69.3 MB/s) - ‘000000575628.jpg’ saved [144561/144561]
#
# --2022-01-30 05:25:03--  http://images.cocodataset.org/train2017/000000285826.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 167511 (164K) [image/jpeg]
# Saving to: ‘000000285826.jpg’
#
# 000000285826.jpg    100%[===================>] 163.58K  --.-KB/s    in 0.02s
#
# 2022-01-30 05:25:03 (6.83 MB/s) - ‘000000285826.jpg’ saved [167511/167511]
#
# --2022-01-30 05:25:03--  http://images.cocodataset.org/train2017/000000417573.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 142760 (139K) [image/jpeg]
# Saving to: ‘000000417573.jpg’
#
# 000000417573.jpg    100%[===================>] 139.41K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:03 (43.4 MB/s) - ‘000000417573.jpg’ saved [142760/142760]
#
# --2022-01-30 05:25:03--  http://images.cocodataset.org/train2017/000000211351.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 199880 (195K) [image/jpeg]
# Saving to: ‘000000211351.jpg’
#
# 000000211351.jpg    100%[===================>] 195.20K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:04 (65.4 MB/s) - ‘000000211351.jpg’ saved [199880/199880]
#
# --2022-01-30 05:25:04--  http://images.cocodataset.org/train2017/000000494574.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 110816 (108K) [image/jpeg]
# Saving to: ‘000000494574.jpg’
#
# 000000494574.jpg    100%[===================>] 108.22K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:04 (64.1 MB/s) - ‘000000494574.jpg’ saved [110816/110816]
#
# --2022-01-30 05:25:04--  http://images.cocodataset.org/train2017/000000273783.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 162119 (158K) [image/jpeg]
# Saving to: ‘000000273783.jpg’
#
# 000000273783.jpg    100%[===================>] 158.32K  --.-KB/s    in 0.02s
#
# 2022-01-30 05:25:04 (6.94 MB/s) - ‘000000273783.jpg’ saved [162119/162119]
#
# --2022-01-30 05:25:04--  http://images.cocodataset.org/train2017/000000531277.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 144165 (141K) [image/jpeg]
# Saving to: ‘000000531277.jpg’
#
# 000000531277.jpg    100%[===================>] 140.79K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:04 (52.7 MB/s) - ‘000000531277.jpg’ saved [144165/144165]
#
# --2022-01-30 05:25:04--  http://images.cocodataset.org/train2017/000000270818.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 160655 (157K) [image/jpeg]
# Saving to: ‘000000270818.jpg’
#
# 000000270818.jpg    100%[===================>] 156.89K  --.-KB/s    in 0.07s
#
# 2022-01-30 05:25:04 (2.12 MB/s) - ‘000000270818.jpg’ saved [160655/160655]
#
# --2022-01-30 05:25:04--  http://images.cocodataset.org/train2017/000000392358.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 121725 (119K) [image/jpeg]
# Saving to: ‘000000392358.jpg’
#
# 000000392358.jpg    100%[===================>] 118.87K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:04 (38.3 MB/s) - ‘000000392358.jpg’ saved [121725/121725]
#
# --2022-01-30 05:25:04--  http://images.cocodataset.org/train2017/000000173821.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 85134 (83K) [image/jpeg]
# Saving to: ‘000000173821.jpg’
#
# 000000173821.jpg    100%[===================>]  83.14K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:04 (53.9 MB/s) - ‘000000173821.jpg’ saved [85134/85134]
#
# --2022-01-30 05:25:04--  http://images.cocodataset.org/train2017/000000552880.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 158047 (154K) [image/jpeg]
# Saving to: ‘000000552880.jpg’
#
# 000000552880.jpg    100%[===================>] 154.34K  --.-KB/s    in 0.006s
#
# 2022-01-30 05:25:04 (25.8 MB/s) - ‘000000552880.jpg’ saved [158047/158047]
#
# --2022-01-30 05:25:04--  http://images.cocodataset.org/train2017/000000556500.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 87565 (86K) [image/jpeg]
# Saving to: ‘000000556500.jpg’
#
# 000000556500.jpg    100%[===================>]  85.51K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:05 (53.8 MB/s) - ‘000000556500.jpg’ saved [87565/87565]
#
# --2022-01-30 05:25:05--  http://images.cocodataset.org/train2017/000000192167.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 21321 (21K) [image/jpeg]
# Saving to: ‘000000192167.jpg’
#
# 000000192167.jpg    100%[===================>]  20.82K  --.-KB/s    in 0.001s
#
# 2022-01-30 05:25:05 (20.2 MB/s) - ‘000000192167.jpg’ saved [21321/21321]
#
# --2022-01-30 05:25:05--  http://images.cocodataset.org/train2017/000000197605.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 132630 (130K) [image/jpeg]
# Saving to: ‘000000197605.jpg’
#
# 000000197605.jpg    100%[===================>] 129.52K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:05 (36.5 MB/s) - ‘000000197605.jpg’ saved [132630/132630]
#
# --2022-01-30 05:25:05--  http://images.cocodataset.org/train2017/000000330934.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 143182 (140K) [image/jpeg]
# Saving to: ‘000000330934.jpg’
#
# 000000330934.jpg    100%[===================>] 139.83K  --.-KB/s    in 0.01s
#
# 2022-01-30 05:25:05 (9.41 MB/s) - ‘000000330934.jpg’ saved [143182/143182]
#
# --2022-01-30 05:25:05--  http://images.cocodataset.org/train2017/000000176955.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 183940 (180K) [image/jpeg]
# Saving to: ‘000000176955.jpg’
#
# 000000176955.jpg    100%[===================>] 179.63K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:25:05 (39.4 MB/s) - ‘000000176955.jpg’ saved [183940/183940]
#
# --2022-01-30 05:25:05--  http://images.cocodataset.org/train2017/000000519209.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 148062 (145K) [image/jpeg]
# Saving to: ‘000000519209.jpg’
#
# 000000519209.jpg    100%[===================>] 144.59K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:05 (60.0 MB/s) - ‘000000519209.jpg’ saved [148062/148062]
#
# --2022-01-30 05:25:05--  http://images.cocodataset.org/train2017/000000157450.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 161633 (158K) [image/jpeg]
# Saving to: ‘000000157450.jpg’
#
# 000000157450.jpg    100%[===================>] 157.84K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:05 (45.1 MB/s) - ‘000000157450.jpg’ saved [161633/161633]
#
# --2022-01-30 05:25:05--  http://images.cocodataset.org/train2017/000000285099.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 93396 (91K) [image/jpeg]
# Saving to: ‘000000285099.jpg’
#
# 000000285099.jpg    100%[===================>]  91.21K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:05 (48.7 MB/s) - ‘000000285099.jpg’ saved [93396/93396]
#
# --2022-01-30 05:25:05--  http://images.cocodataset.org/train2017/000000388847.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 231539 (226K) [image/jpeg]
# Saving to: ‘000000388847.jpg’
#
# 000000388847.jpg    100%[===================>] 226.11K  --.-KB/s    in 0.02s
#
# 2022-01-30 05:25:05 (9.23 MB/s) - ‘000000388847.jpg’ saved [231539/231539]
#
# --2022-01-30 05:25:05--  http://images.cocodataset.org/train2017/000000542662.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 129109 (126K) [image/jpeg]
# Saving to: ‘000000542662.jpg’
#
# 000000542662.jpg    100%[===================>] 126.08K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:06 (65.0 MB/s) - ‘000000542662.jpg’ saved [129109/129109]
#
# --2022-01-30 05:25:06--  http://images.cocodataset.org/train2017/000000376776.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 120354 (118K) [image/jpeg]
# Saving to: ‘000000376776.jpg’
#
# 000000376776.jpg    100%[===================>] 117.53K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:06 (33.2 MB/s) - ‘000000376776.jpg’ saved [120354/120354]
#
# --2022-01-30 05:25:06--  http://images.cocodataset.org/train2017/000000569567.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 96769 (95K) [image/jpeg]
# Saving to: ‘000000569567.jpg’
#
# 000000569567.jpg    100%[===================>]  94.50K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:06 (56.4 MB/s) - ‘000000569567.jpg’ saved [96769/96769]
#
# --2022-01-30 05:25:06--  http://images.cocodataset.org/train2017/000000366528.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 76977 (75K) [image/jpeg]
# Saving to: ‘000000366528.jpg’
#
# 000000366528.jpg    100%[===================>]  75.17K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:06 (26.6 MB/s) - ‘000000366528.jpg’ saved [76977/76977]
#
# --2022-01-30 05:25:06--  http://images.cocodataset.org/train2017/000000288737.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 303810 (297K) [image/jpeg]
# Saving to: ‘000000288737.jpg’
#
# 000000288737.jpg    100%[===================>] 296.69K  --.-KB/s    in 0.005s
#
# 2022-01-30 05:25:06 (60.4 MB/s) - ‘000000288737.jpg’ saved [303810/303810]
#
# --2022-01-30 05:25:06--  http://images.cocodataset.org/train2017/000000297779.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 81503 (80K) [image/jpeg]
# Saving to: ‘000000297779.jpg’
#
# 000000297779.jpg    100%[===================>]  79.59K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:06 (36.8 MB/s) - ‘000000297779.jpg’ saved [81503/81503]
#
# --2022-01-30 05:25:06--  http://images.cocodataset.org/train2017/000000475984.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 88113 (86K) [image/jpeg]
# Saving to: ‘000000475984.jpg’
#
# 000000475984.jpg    100%[===================>]  86.05K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:06 (53.9 MB/s) - ‘000000475984.jpg’ saved [88113/88113]
#
# --2022-01-30 05:25:06--  http://images.cocodataset.org/train2017/000000315549.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 105200 (103K) [image/jpeg]
# Saving to: ‘000000315549.jpg’
#
# 000000315549.jpg    100%[===================>] 102.73K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:06 (36.2 MB/s) - ‘000000315549.jpg’ saved [105200/105200]
#
# --2022-01-30 05:25:06--  http://images.cocodataset.org/train2017/000000239205.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 102970 (101K) [image/jpeg]
# Saving to: ‘000000239205.jpg’
#
# 000000239205.jpg    100%[===================>] 100.56K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:25:06 (26.0 MB/s) - ‘000000239205.jpg’ saved [102970/102970]
#
# --2022-01-30 05:25:06--  http://images.cocodataset.org/train2017/000000131343.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 204088 (199K) [image/jpeg]
# Saving to: ‘000000131343.jpg’
#
# 000000131343.jpg    100%[===================>] 199.30K  --.-KB/s    in 0.1s
#
# 2022-01-30 05:25:07 (1.82 MB/s) - ‘000000131343.jpg’ saved [204088/204088]
#
# --2022-01-30 05:25:07--  http://images.cocodataset.org/train2017/000000112409.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 182496 (178K) [image/jpeg]
# Saving to: ‘000000112409.jpg’
#
# 000000112409.jpg    100%[===================>] 178.22K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:25:07 (44.6 MB/s) - ‘000000112409.jpg’ saved [182496/182496]
#
# --2022-01-30 05:25:07--  http://images.cocodataset.org/train2017/000000499425.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 95186 (93K) [image/jpeg]
# Saving to: ‘000000499425.jpg’
#
# 000000499425.jpg    100%[===================>]  92.96K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:07 (54.4 MB/s) - ‘000000499425.jpg’ saved [95186/95186]
#
# --2022-01-30 05:25:07--  http://images.cocodataset.org/train2017/000000413374.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 155110 (151K) [image/jpeg]
# Saving to: ‘000000413374.jpg’
#
# 000000413374.jpg    100%[===================>] 151.47K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:07 (72.4 MB/s) - ‘000000413374.jpg’ saved [155110/155110]
#
# --2022-01-30 05:25:07--  http://images.cocodataset.org/train2017/000000540753.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 115298 (113K) [image/jpeg]
# Saving to: ‘000000540753.jpg’
#
# 000000540753.jpg    100%[===================>] 112.60K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:25:07 (27.0 MB/s) - ‘000000540753.jpg’ saved [115298/115298]
#
# --2022-01-30 05:25:07--  http://images.cocodataset.org/train2017/000000334039.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 213932 (209K) [image/jpeg]
# Saving to: ‘000000334039.jpg’
#
# 000000334039.jpg    100%[===================>] 208.92K  --.-KB/s    in 0.008s
#
# 2022-01-30 05:25:07 (26.8 MB/s) - ‘000000334039.jpg’ saved [213932/213932]
#
# --2022-01-30 05:25:07--  http://images.cocodataset.org/train2017/000000111583.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 65945 (64K) [image/jpeg]
# Saving to: ‘000000111583.jpg’
#
# 000000111583.jpg    100%[===================>]  64.40K  --.-KB/s    in 0.001s
#
# 2022-01-30 05:25:07 (43.7 MB/s) - ‘000000111583.jpg’ saved [65945/65945]
#
# --2022-01-30 05:25:07--  http://images.cocodataset.org/train2017/000000490570.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 224005 (219K) [image/jpeg]
# Saving to: ‘000000490570.jpg’
#
# 000000490570.jpg    100%[===================>] 218.75K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:07 (79.9 MB/s) - ‘000000490570.jpg’ saved [224005/224005]
#
# --2022-01-30 05:25:07--  http://images.cocodataset.org/train2017/000000273606.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 102989 (101K) [image/jpeg]
# Saving to: ‘000000273606.jpg’
#
# 000000273606.jpg    100%[===================>] 100.58K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:07 (59.8 MB/s) - ‘000000273606.jpg’ saved [102989/102989]
#
# --2022-01-30 05:25:07--  http://images.cocodataset.org/train2017/000000465759.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 107941 (105K) [image/jpeg]
# Saving to: ‘000000465759.jpg’
#
# 000000465759.jpg    100%[===================>] 105.41K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:07 (61.2 MB/s) - ‘000000465759.jpg’ saved [107941/107941]
#
# --2022-01-30 05:25:07--  http://images.cocodataset.org/train2017/000000147505.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 175197 (171K) [image/jpeg]
# Saving to: ‘000000147505.jpg’
#
# 000000147505.jpg    100%[===================>] 171.09K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:08 (48.5 MB/s) - ‘000000147505.jpg’ saved [175197/175197]
#
# --2022-01-30 05:25:08--  http://images.cocodataset.org/train2017/000000141348.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 129727 (127K) [image/jpeg]
# Saving to: ‘000000141348.jpg’
#
# 000000141348.jpg    100%[===================>] 126.69K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:08 (36.0 MB/s) - ‘000000141348.jpg’ saved [129727/129727]
#
# --2022-01-30 05:25:08--  http://images.cocodataset.org/train2017/000000310702.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 114370 (112K) [image/jpeg]
# Saving to: ‘000000310702.jpg’
#
# 000000310702.jpg    100%[===================>] 111.69K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:08 (70.1 MB/s) - ‘000000310702.jpg’ saved [114370/114370]
#
# --2022-01-30 05:25:08--  http://images.cocodataset.org/train2017/000000190645.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 122449 (120K) [image/jpeg]
# Saving to: ‘000000190645.jpg’
#
# 000000190645.jpg    100%[===================>] 119.58K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:08 (36.7 MB/s) - ‘000000190645.jpg’ saved [122449/122449]
#
# --2022-01-30 05:25:08--  http://images.cocodataset.org/train2017/000000575331.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 151766 (148K) [image/jpeg]
# Saving to: ‘000000575331.jpg’
#
# 000000575331.jpg    100%[===================>] 148.21K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:08 (47.6 MB/s) - ‘000000575331.jpg’ saved [151766/151766]
#
# --2022-01-30 05:25:08--  http://images.cocodataset.org/train2017/000000259371.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 177153 (173K) [image/jpeg]
# ...
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 275602 (269K) [image/jpeg]
# Saving to: ‘000000104943.jpg’
#
# 000000104943.jpg    100%[===================>] 269.14K  --.-KB/s    in 0.005s
#
# 2022-01-30 05:25:45 (48.0 MB/s) - ‘000000104943.jpg’ saved [275602/275602]
#
# --2022-01-30 05:25:45--  http://images.cocodataset.org/train2017/000000363128.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 119632 (117K) [image/jpeg]
# Saving to: ‘000000363128.jpg’
#
# 000000363128.jpg    100%[===================>] 116.83K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:45 (51.0 MB/s) - ‘000000363128.jpg’ saved [119632/119632]
#
# --2022-01-30 05:25:45--  http://images.cocodataset.org/train2017/000000445462.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 291397 (285K) [image/jpeg]
# Saving to: ‘000000445462.jpg’
#
# 000000445462.jpg    100%[===================>] 284.57K  --.-KB/s    in 0.005s
#
# 2022-01-30 05:25:45 (54.0 MB/s) - ‘000000445462.jpg’ saved [291397/291397]
#
# --2022-01-30 05:25:45--  http://images.cocodataset.org/train2017/000000536390.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 209754 (205K) [image/jpeg]
# Saving to: ‘000000536390.jpg’
#
# 000000536390.jpg    100%[===================>] 204.84K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:45 (70.4 MB/s) - ‘000000536390.jpg’ saved [209754/209754]
#
# --2022-01-30 05:25:45--  http://images.cocodataset.org/train2017/000000540795.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 134281 (131K) [image/jpeg]
# Saving to: ‘000000540795.jpg’
#
# 000000540795.jpg    100%[===================>] 131.13K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:45 (41.6 MB/s) - ‘000000540795.jpg’ saved [134281/134281]
#
# --2022-01-30 05:25:45--  http://images.cocodataset.org/train2017/000000358523.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 349203 (341K) [image/jpeg]
# Saving to: ‘000000358523.jpg’
#
# 000000358523.jpg    100%[===================>] 341.02K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:25:45 (74.8 MB/s) - ‘000000358523.jpg’ saved [349203/349203]
#
# --2022-01-30 05:25:45--  http://images.cocodataset.org/train2017/000000364937.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 55055 (54K) [image/jpeg]
# Saving to: ‘000000364937.jpg’
#
# 000000364937.jpg    100%[===================>]  53.76K  --.-KB/s    in 0.001s
#
# 2022-01-30 05:25:45 (36.7 MB/s) - ‘000000364937.jpg’ saved [55055/55055]
#
# --2022-01-30 05:25:45--  http://images.cocodataset.org/train2017/000000285046.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 175997 (172K) [image/jpeg]
# Saving to: ‘000000285046.jpg’
#
# 000000285046.jpg    100%[===================>] 171.87K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:45 (62.6 MB/s) - ‘000000285046.jpg’ saved [175997/175997]
#
# --2022-01-30 05:25:45--  http://images.cocodataset.org/train2017/000000202774.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 111092 (108K) [image/jpeg]
# Saving to: ‘000000202774.jpg’
#
# 000000202774.jpg    100%[===================>] 108.49K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:45 (62.1 MB/s) - ‘000000202774.jpg’ saved [111092/111092]
#
# --2022-01-30 05:25:45--  http://images.cocodataset.org/train2017/000000415243.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 122754 (120K) [image/jpeg]
# Saving to: ‘000000415243.jpg’
#
# 000000415243.jpg    100%[===================>] 119.88K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:45 (65.8 MB/s) - ‘000000415243.jpg’ saved [122754/122754]
#
# --2022-01-30 05:25:45--  http://images.cocodataset.org/train2017/000000565858.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 40335 (39K) [image/jpeg]
# Saving to: ‘000000565858.jpg’
#
# 000000565858.jpg    100%[===================>]  39.39K  --.-KB/s    in 0.001s
#
# 2022-01-30 05:25:46 (27.7 MB/s) - ‘000000565858.jpg’ saved [40335/40335]
#
# --2022-01-30 05:25:46--  http://images.cocodataset.org/train2017/000000361397.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 259653 (254K) [image/jpeg]
# Saving to: ‘000000361397.jpg’
#
# 000000361397.jpg    100%[===================>] 253.57K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:25:46 (67.0 MB/s) - ‘000000361397.jpg’ saved [259653/259653]
#
# --2022-01-30 05:25:46--  http://images.cocodataset.org/train2017/000000314204.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 92714 (91K) [image/jpeg]
# Saving to: ‘000000314204.jpg’
#
# 000000314204.jpg    100%[===================>]  90.54K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:46 (29.0 MB/s) - ‘000000314204.jpg’ saved [92714/92714]
#
# --2022-01-30 05:25:46--  http://images.cocodataset.org/train2017/000000211389.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 84159 (82K) [image/jpeg]
# Saving to: ‘000000211389.jpg’
#
# 000000211389.jpg    100%[===================>]  82.19K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:46 (31.3 MB/s) - ‘000000211389.jpg’ saved [84159/84159]
#
# --2022-01-30 05:25:46--  http://images.cocodataset.org/train2017/000000144590.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 128771 (126K) [image/jpeg]
# Saving to: ‘000000144590.jpg’
#
# 000000144590.jpg    100%[===================>] 125.75K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:46 (69.5 MB/s) - ‘000000144590.jpg’ saved [128771/128771]
#
# --2022-01-30 05:25:46--  http://images.cocodataset.org/train2017/000000330609.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 81885 (80K) [image/jpeg]
# Saving to: ‘000000330609.jpg’
#
# 000000330609.jpg    100%[===================>]  79.97K  --.-KB/s    in 0.001s
#
# 2022-01-30 05:25:46 (53.7 MB/s) - ‘000000330609.jpg’ saved [81885/81885]
#
# --2022-01-30 05:25:46--  http://images.cocodataset.org/train2017/000000234642.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 156513 (153K) [image/jpeg]
# Saving to: ‘000000234642.jpg’
#
# 000000234642.jpg    100%[===================>] 152.84K  --.-KB/s    in 0.01s
#
# 2022-01-30 05:25:46 (11.8 MB/s) - ‘000000234642.jpg’ saved [156513/156513]
#
# --2022-01-30 05:25:46--  http://images.cocodataset.org/train2017/000000340316.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 234226 (229K) [image/jpeg]
# Saving to: ‘000000340316.jpg’
#
# 000000340316.jpg    100%[===================>] 228.74K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:25:46 (56.3 MB/s) - ‘000000340316.jpg’ saved [234226/234226]
#
# --2022-01-30 05:25:46--  http://images.cocodataset.org/train2017/000000399818.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 99713 (97K) [image/jpeg]
# Saving to: ‘000000399818.jpg’
#
# 000000399818.jpg    100%[===================>]  97.38K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:46 (62.2 MB/s) - ‘000000399818.jpg’ saved [99713/99713]
#
# --2022-01-30 05:25:46--  http://images.cocodataset.org/train2017/000000343200.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 179878 (176K) [image/jpeg]
# Saving to: ‘000000343200.jpg’
#
# 000000343200.jpg    100%[===================>] 175.66K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:47 (50.2 MB/s) - ‘000000343200.jpg’ saved [179878/179878]
#
# --2022-01-30 05:25:47--  http://images.cocodataset.org/train2017/000000498782.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 123527 (121K) [image/jpeg]
# Saving to: ‘000000498782.jpg’
#
# 000000498782.jpg    100%[===================>] 120.63K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:25:47 (26.9 MB/s) - ‘000000498782.jpg’ saved [123527/123527]
#
# --2022-01-30 05:25:47--  http://images.cocodataset.org/train2017/000000554336.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 21555 (21K) [image/jpeg]
# Saving to: ‘000000554336.jpg’
#
# 000000554336.jpg    100%[===================>]  21.05K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:47 (13.4 MB/s) - ‘000000554336.jpg’ saved [21555/21555]
#
# --2022-01-30 05:25:47--  http://images.cocodataset.org/train2017/000000248744.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 121359 (119K) [image/jpeg]
# Saving to: ‘000000248744.jpg’
#
# 000000248744.jpg    100%[===================>] 118.51K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:47 (56.4 MB/s) - ‘000000248744.jpg’ saved [121359/121359]
#
# --2022-01-30 05:25:47--  http://images.cocodataset.org/train2017/000000107900.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 89343 (87K) [image/jpeg]
# Saving to: ‘000000107900.jpg’
#
# 000000107900.jpg    100%[===================>]  87.25K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:47 (53.1 MB/s) - ‘000000107900.jpg’ saved [89343/89343]
#
# --2022-01-30 05:25:47--  http://images.cocodataset.org/train2017/000000507776.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 286971 (280K) [image/jpeg]
# Saving to: ‘000000507776.jpg’
#
# 000000507776.jpg    100%[===================>] 280.25K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:47 (91.3 MB/s) - ‘000000507776.jpg’ saved [286971/286971]
#
# --2022-01-30 05:25:47--  http://images.cocodataset.org/train2017/000000436108.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 191049 (187K) [image/jpeg]
# Saving to: ‘000000436108.jpg’
#
# 000000436108.jpg    100%[===================>] 186.57K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:47 (66.7 MB/s) - ‘000000436108.jpg’ saved [191049/191049]
#
# --2022-01-30 05:25:47--  http://images.cocodataset.org/train2017/000000575675.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 310495 (303K) [image/jpeg]
# Saving to: ‘000000575675.jpg’
#
# 000000575675.jpg    100%[===================>] 303.22K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:47 (92.5 MB/s) - ‘000000575675.jpg’ saved [310495/310495]
#
# --2022-01-30 05:25:47--  http://images.cocodataset.org/train2017/000000225100.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 83922 (82K) [image/jpeg]
# Saving to: ‘000000225100.jpg’
#
# 000000225100.jpg    100%[===================>]  81.96K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:47 (26.7 MB/s) - ‘000000225100.jpg’ saved [83922/83922]
#
# --2022-01-30 05:25:47--  http://images.cocodataset.org/train2017/000000355678.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 164933 (161K) [image/jpeg]
# Saving to: ‘000000355678.jpg’
#
# 000000355678.jpg    100%[===================>] 161.07K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:47 (60.3 MB/s) - ‘000000355678.jpg’ saved [164933/164933]
#
# --2022-01-30 05:25:47--  http://images.cocodataset.org/train2017/000000475084.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 140157 (137K) [image/jpeg]
# Saving to: ‘000000475084.jpg’
#
# 000000475084.jpg    100%[===================>] 136.87K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:25:48 (33.8 MB/s) - ‘000000475084.jpg’ saved [140157/140157]
#
# --2022-01-30 05:25:48--  http://images.cocodataset.org/train2017/000000134564.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 124945 (122K) [image/jpeg]
# Saving to: ‘000000134564.jpg’
#
# 000000134564.jpg    100%[===================>] 122.02K  --.-KB/s    in 0.01s
#
# 2022-01-30 05:25:48 (8.20 MB/s) - ‘000000134564.jpg’ saved [124945/124945]
#
# --2022-01-30 05:25:48--  http://images.cocodataset.org/train2017/000000447681.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 186019 (182K) [image/jpeg]
# Saving to: ‘000000447681.jpg’
#
# 000000447681.jpg    100%[===================>] 181.66K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:25:48 (49.4 MB/s) - ‘000000447681.jpg’ saved [186019/186019]
#
# --2022-01-30 05:25:48--  http://images.cocodataset.org/train2017/000000501534.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 67971 (66K) [image/jpeg]
# Saving to: ‘000000501534.jpg’
#
# 000000501534.jpg    100%[===================>]  66.38K  --.-KB/s    in 0.001s
#
# 2022-01-30 05:25:48 (47.9 MB/s) - ‘000000501534.jpg’ saved [67971/67971]
#
# --2022-01-30 05:25:48--  http://images.cocodataset.org/train2017/000000544060.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 180872 (177K) [image/jpeg]
# Saving to: ‘000000544060.jpg’
#
# 000000544060.jpg    100%[===================>] 176.63K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:48 (76.9 MB/s) - ‘000000544060.jpg’ saved [180872/180872]
#
# --2022-01-30 05:25:48--  http://images.cocodataset.org/train2017/000000577399.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 88052 (86K) [image/jpeg]
# Saving to: ‘000000577399.jpg’
#
# 000000577399.jpg    100%[===================>]  85.99K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:25:48 (22.1 MB/s) - ‘000000577399.jpg’ saved [88052/88052]
#
# --2022-01-30 05:25:48--  http://images.cocodataset.org/train2017/000000258364.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 196852 (192K) [image/jpeg]
# Saving to: ‘000000258364.jpg’
#
# 000000258364.jpg    100%[===================>] 192.24K  --.-KB/s    in 0.09s
#
# 2022-01-30 05:25:48 (2.02 MB/s) - ‘000000258364.jpg’ saved [196852/196852]
#
# --2022-01-30 05:25:48--  http://images.cocodataset.org/train2017/000000270696.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 105698 (103K) [image/jpeg]
# Saving to: ‘000000270696.jpg’
#
# 000000270696.jpg    100%[===================>] 103.22K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:25:48 (45.2 MB/s) - ‘000000270696.jpg’ saved [105698/105698]
#
# --2022-01-30 05:25:48--  http://images.cocodataset.org/train2017/000000229318.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 250610 (245K) [image/jpeg]
# Saving to: ‘000000229318.jpg’
#
# 000000229318.jpg    100%[===================>] 244.74K  --.-KB/s    in 0.005s
#
# 2022-01-30 05:25:48 (52.7 MB/s) - ‘000000229318.jpg’ saved [250610/250610]
#
# --2022-01-30 05:25:48--  http://images.cocodataset.org/train2017/000000497261.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 156755 (153K) [image/jpeg]
# Saving to: ‘000000497261.jpg’
#
# 000000497261.jpg    100%[===================>] 153.08K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:25:49 (43.9 MB/s) - ‘000000497261.jpg’ saved [156755/156755]
#
# FINISHED --2022-01-30 05:25:49--
# Total wall clock time: 1h 17m 30s
# Downloaded: 43152 files, 6.5G in 4m 47s (23.2 MB/s)

# %% [markdown]
# downloading cv images

# %%
cd /content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data
# Out:
# /content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data

# %%
# ! echo cv_url_file.txt
# Out:
# cv_url_file.txt

# %%
# with open("cv_url_file.txt", 'w') as file:
#   for row in cv_images_urls:
#       s = "".join(map(str, row))
#       file.write(s+'\n')

# %%
cd /content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data/person cv images
# Out:
# /content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data/person cv images

# %%
# ! wget -i /content/drive/MyDrive/'Human Pose Estimation'/'Human Pose Estimation Data'/cv_url_file.txt
# Out:
# Streaming output truncated to the last 5000 lines.
# Length: 155869 (152K) [image/jpeg]
# Saving to: ‘000000177213.jpg’
#
# 000000177213.jpg    100%[===================>] 152.22K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:03 (36.8 MB/s) - ‘000000177213.jpg’ saved [155869/155869]
#
# --2022-01-30 05:31:03--  http://images.cocodataset.org/val2017/000000213830.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 229985 (225K) [image/jpeg]
# Saving to: ‘000000213830.jpg’
#
# 000000213830.jpg    100%[===================>] 224.59K  --.-KB/s    in 0.02s
#
# 2022-01-30 05:31:03 (11.8 MB/s) - ‘000000213830.jpg’ saved [229985/229985]
#
# --2022-01-30 05:31:03--  http://images.cocodataset.org/val2017/000000451155.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 36662 (36K) [image/jpeg]
# Saving to: ‘000000451155.jpg’
#
# 000000451155.jpg    100%[===================>]  35.80K  --.-KB/s    in 0.001s
#
# 2022-01-30 05:31:03 (33.1 MB/s) - ‘000000451155.jpg’ saved [36662/36662]
#
# --2022-01-30 05:31:03--  http://images.cocodataset.org/val2017/000000209829.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 117509 (115K) [image/jpeg]
# Saving to: ‘000000209829.jpg’
#
# 000000209829.jpg    100%[===================>] 114.75K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:03 (25.3 MB/s) - ‘000000209829.jpg’ saved [117509/117509]
#
# --2022-01-30 05:31:03--  http://images.cocodataset.org/val2017/000000516318.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 119499 (117K) [image/jpeg]
# Saving to: ‘000000516318.jpg’
#
# 000000516318.jpg    100%[===================>] 116.70K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:03 (57.6 MB/s) - ‘000000516318.jpg’ saved [119499/119499]
#
# --2022-01-30 05:31:03--  http://images.cocodataset.org/val2017/000000239347.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 159857 (156K) [image/jpeg]
# Saving to: ‘000000239347.jpg’
#
# 000000239347.jpg    100%[===================>] 156.11K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:04 (69.1 MB/s) - ‘000000239347.jpg’ saved [159857/159857]
#
# --2022-01-30 05:31:04--  http://images.cocodataset.org/val2017/000000190307.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 273737 (267K) [image/jpeg]
# Saving to: ‘000000190307.jpg’
#
# 000000190307.jpg    100%[===================>] 267.32K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:04 (84.0 MB/s) - ‘000000190307.jpg’ saved [273737/273737]
#
# --2022-01-30 05:31:04--  http://images.cocodataset.org/val2017/000000171757.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 118728 (116K) [image/jpeg]
# Saving to: ‘000000171757.jpg’
#
# 000000171757.jpg    100%[===================>] 115.95K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:04 (37.9 MB/s) - ‘000000171757.jpg’ saved [118728/118728]
#
# --2022-01-30 05:31:04--  http://images.cocodataset.org/val2017/000000115898.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 219640 (214K) [image/jpeg]
# Saving to: ‘000000115898.jpg’
#
# 000000115898.jpg    100%[===================>] 214.49K  --.-KB/s    in 0.01s
#
# 2022-01-30 05:31:04 (21.8 MB/s) - ‘000000115898.jpg’ saved [219640/219640]
#
# --2022-01-30 05:31:04--  http://images.cocodataset.org/val2017/000000518326.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 248534 (243K) [image/jpeg]
# Saving to: ‘000000518326.jpg’
#
# 000000518326.jpg    100%[===================>] 242.71K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:04 (67.9 MB/s) - ‘000000518326.jpg’ saved [248534/248534]
#
# --2022-01-30 05:31:04--  http://images.cocodataset.org/val2017/000000170191.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 126080 (123K) [image/jpeg]
# Saving to: ‘000000170191.jpg’
#
# 000000170191.jpg    100%[===================>] 123.12K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:04 (64.9 MB/s) - ‘000000170191.jpg’ saved [126080/126080]
#
# --2022-01-30 05:31:04--  http://images.cocodataset.org/val2017/000000425702.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 121657 (119K) [image/jpeg]
# Saving to: ‘000000425702.jpg’
#
# 000000425702.jpg    100%[===================>] 118.81K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:04 (30.9 MB/s) - ‘000000425702.jpg’ saved [121657/121657]
#
# --2022-01-30 05:31:04--  http://images.cocodataset.org/val2017/000000110449.jpg
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.217.203.73|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 82037 (80K) [image/jpeg]
# Saving to: ‘000000110449.jpg’
#
# 000000110449.jpg    100%[===================>]  80.11K  --.-KB/s    in 0.06s
#
# 2022-01-30 05:31:04 (1.38 MB/s) - ‘000000110449.jpg’ saved [82037/82037]
#
# --2022-01-30 05:31:04--  http://images.cocodataset.org/val2017/000000261535.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 203441 (199K) [image/jpeg]
# Saving to: ‘000000261535.jpg’
#
# 000000261535.jpg    100%[===================>] 198.67K  --.-KB/s    in 0.03s
#
# 2022-01-30 05:31:05 (7.23 MB/s) - ‘000000261535.jpg’ saved [203441/203441]
#
# --2022-01-30 05:31:05--  http://images.cocodataset.org/val2017/000000316404.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 152184 (149K) [image/jpeg]
# Saving to: ‘000000316404.jpg’
#
# 000000316404.jpg    100%[===================>] 148.62K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:05 (44.4 MB/s) - ‘000000316404.jpg’ saved [152184/152184]
#
# --2022-01-30 05:31:05--  http://images.cocodataset.org/val2017/000000422670.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 78723 (77K) [image/jpeg]
# Saving to: ‘000000422670.jpg’
#
# 000000422670.jpg    100%[===================>]  76.88K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:05 (28.6 MB/s) - ‘000000422670.jpg’ saved [78723/78723]
#
# --2022-01-30 05:31:05--  http://images.cocodataset.org/val2017/000000371042.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 194759 (190K) [image/jpeg]
# Saving to: ‘000000371042.jpg’
#
# 000000371042.jpg    100%[===================>] 190.19K  --.-KB/s    in 0.02s
#
# 2022-01-30 05:31:05 (11.9 MB/s) - ‘000000371042.jpg’ saved [194759/194759]
#
# --2022-01-30 05:31:05--  http://images.cocodataset.org/val2017/000000129492.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 121196 (118K) [image/jpeg]
# Saving to: ‘000000129492.jpg’
#
# 000000129492.jpg    100%[===================>] 118.36K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:05 (69.4 MB/s) - ‘000000129492.jpg’ saved [121196/121196]
#
# --2022-01-30 05:31:05--  http://images.cocodataset.org/val2017/000000318138.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 67942 (66K) [image/jpeg]
# Saving to: ‘000000318138.jpg’
#
# 000000318138.jpg    100%[===================>]  66.35K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:05 (24.7 MB/s) - ‘000000318138.jpg’ saved [67942/67942]
#
# --2022-01-30 05:31:05--  http://images.cocodataset.org/val2017/000000137106.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 63064 (62K) [image/jpeg]
# Saving to: ‘000000137106.jpg’
#
# 000000137106.jpg    100%[===================>]  61.59K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:05 (23.3 MB/s) - ‘000000137106.jpg’ saved [63064/63064]
#
# --2022-01-30 05:31:05--  http://images.cocodataset.org/val2017/000000175251.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 155528 (152K) [image/jpeg]
# Saving to: ‘000000175251.jpg’
#
# 000000175251.jpg    100%[===================>] 151.88K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:05 (44.4 MB/s) - ‘000000175251.jpg’ saved [155528/155528]
#
# --2022-01-30 05:31:05--  http://images.cocodataset.org/val2017/000000273760.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 237862 (232K) [image/jpeg]
# Saving to: ‘000000273760.jpg’
#
# 000000273760.jpg    100%[===================>] 232.29K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:05 (85.3 MB/s) - ‘000000273760.jpg’ saved [237862/237862]
#
# --2022-01-30 05:31:05--  http://images.cocodataset.org/val2017/000000229111.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 113899 (111K) [image/jpeg]
# Saving to: ‘000000229111.jpg’
#
# 000000229111.jpg    100%[===================>] 111.23K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:05 (32.3 MB/s) - ‘000000229111.jpg’ saved [113899/113899]
#
# --2022-01-30 05:31:05--  http://images.cocodataset.org/val2017/000000200421.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 120785 (118K) [image/jpeg]
# Saving to: ‘000000200421.jpg’
#
# 000000200421.jpg    100%[===================>] 117.95K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:06 (35.3 MB/s) - ‘000000200421.jpg’ saved [120785/120785]
#
# --2022-01-30 05:31:06--  http://images.cocodataset.org/val2017/000000289415.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 150850 (147K) [image/jpeg]
# Saving to: ‘000000289415.jpg’
#
# 000000289415.jpg    100%[===================>] 147.31K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:06 (48.3 MB/s) - ‘000000289415.jpg’ saved [150850/150850]
#
# --2022-01-30 05:31:06--  http://images.cocodataset.org/val2017/000000482735.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 161157 (157K) [image/jpeg]
# Saving to: ‘000000482735.jpg’
#
# 000000482735.jpg    100%[===================>] 157.38K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:06 (67.3 MB/s) - ‘000000482735.jpg’ saved [161157/161157]
#
# --2022-01-30 05:31:06--  http://images.cocodataset.org/val2017/000000191672.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 188399 (184K) [image/jpeg]
# Saving to: ‘000000191672.jpg’
#
# 000000191672.jpg    100%[===================>] 183.98K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:06 (54.3 MB/s) - ‘000000191672.jpg’ saved [188399/188399]
#
# --2022-01-30 05:31:06--  http://images.cocodataset.org/val2017/000000489611.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 133189 (130K) [image/jpeg]
# Saving to: ‘000000489611.jpg’
#
# 000000489611.jpg    100%[===================>] 130.07K  --.-KB/s    in 0.01s
#
# 2022-01-30 05:31:06 (10.6 MB/s) - ‘000000489611.jpg’ saved [133189/133189]
#
# --2022-01-30 05:31:06--  http://images.cocodataset.org/val2017/000000441491.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 146644 (143K) [image/jpeg]
# Saving to: ‘000000441491.jpg’
#
# 000000441491.jpg    100%[===================>] 143.21K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:06 (41.0 MB/s) - ‘000000441491.jpg’ saved [146644/146644]
#
# --2022-01-30 05:31:06--  http://images.cocodataset.org/val2017/000000468577.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 96245 (94K) [image/jpeg]
# Saving to: ‘000000468577.jpg’
#
# 000000468577.jpg    100%[===================>]  93.99K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:06 (47.9 MB/s) - ‘000000468577.jpg’ saved [96245/96245]
#
# --2022-01-30 05:31:06--  http://images.cocodataset.org/val2017/000000463174.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 179345 (175K) [image/jpeg]
# Saving to: ‘000000463174.jpg’
#
# 000000463174.jpg    100%[===================>] 175.14K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:06 (46.2 MB/s) - ‘000000463174.jpg’ saved [179345/179345]
#
# --2022-01-30 05:31:06--  http://images.cocodataset.org/val2017/000000307172.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 191846 (187K) [image/jpeg]
# Saving to: ‘000000307172.jpg’
#
# 000000307172.jpg    100%[===================>] 187.35K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:06 (50.5 MB/s) - ‘000000307172.jpg’ saved [191846/191846]
#
# --2022-01-30 05:31:06--  http://images.cocodataset.org/val2017/000000521717.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 88010 (86K) [image/jpeg]
# Saving to: ‘000000521717.jpg’
#
# 000000521717.jpg    100%[===================>]  85.95K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:06 (51.8 MB/s) - ‘000000521717.jpg’ saved [88010/88010]
#
# --2022-01-30 05:31:06--  http://images.cocodataset.org/val2017/000000498032.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 63845 (62K) [image/jpeg]
# Saving to: ‘000000498032.jpg’
#
# 000000498032.jpg    100%[===================>]  62.35K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:07 (19.2 MB/s) - ‘000000498032.jpg’ saved [63845/63845]
#
# --2022-01-30 05:31:07--  http://images.cocodataset.org/val2017/000000530820.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 124678 (122K) [image/jpeg]
# Saving to: ‘000000530820.jpg’
#
# 000000530820.jpg    100%[===================>] 121.76K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:07 (38.6 MB/s) - ‘000000530820.jpg’ saved [124678/124678]
#
# --2022-01-30 05:31:07--  http://images.cocodataset.org/val2017/000000287347.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 210512 (206K) [image/jpeg]
# Saving to: ‘000000287347.jpg’
#
# 000000287347.jpg    100%[===================>] 205.58K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:07 (49.1 MB/s) - ‘000000287347.jpg’ saved [210512/210512]
#
# --2022-01-30 05:31:07--  http://images.cocodataset.org/val2017/000000199551.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 156300 (153K) [image/jpeg]
# Saving to: ‘000000199551.jpg’
#
# 000000199551.jpg    100%[===================>] 152.64K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:07 (72.1 MB/s) - ‘000000199551.jpg’ saved [156300/156300]
#
# --2022-01-30 05:31:07--  http://images.cocodataset.org/val2017/000000276285.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 236710 (231K) [image/jpeg]
# Saving to: ‘000000276285.jpg’
#
# 000000276285.jpg    100%[===================>] 231.16K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:07 (50.6 MB/s) - ‘000000276285.jpg’ saved [236710/236710]
#
# --2022-01-30 05:31:07--  http://images.cocodataset.org/val2017/000000234607.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 114588 (112K) [image/jpeg]
# Saving to: ‘000000234607.jpg’
#
# 000000234607.jpg    100%[===================>] 111.90K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:07 (36.5 MB/s) - ‘000000234607.jpg’ saved [114588/114588]
#
# --2022-01-30 05:31:07--  http://images.cocodataset.org/val2017/000000238013.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 71041 (69K) [image/jpeg]
# Saving to: ‘000000238013.jpg’
#
# 000000238013.jpg    100%[===================>]  69.38K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:07 (24.4 MB/s) - ‘000000238013.jpg’ saved [71041/71041]
#
# --2022-01-30 05:31:07--  http://images.cocodataset.org/val2017/000000327617.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 160241 (156K) [image/jpeg]
# Saving to: ‘000000327617.jpg’
#
# 000000327617.jpg    100%[===================>] 156.49K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:07 (51.4 MB/s) - ‘000000327617.jpg’ saved [160241/160241]
#
# --2022-01-30 05:31:07--  http://images.cocodataset.org/val2017/000000391140.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 110383 (108K) [image/jpeg]
# Saving to: ‘000000391140.jpg’
#
# 000000391140.jpg    100%[===================>] 107.80K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:07 (60.2 MB/s) - ‘000000391140.jpg’ saved [110383/110383]
#
# --2022-01-30 05:31:07--  http://images.cocodataset.org/val2017/000000415882.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 152721 (149K) [image/jpeg]
# Saving to: ‘000000415882.jpg’
#
# 000000415882.jpg    100%[===================>] 149.14K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:07 (37.0 MB/s) - ‘000000415882.jpg’ saved [152721/152721]
#
# --2022-01-30 05:31:07--  http://images.cocodataset.org/val2017/000000551439.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 114291 (112K) [image/jpeg]
# Saving to: ‘000000551439.jpg’
#
# 000000551439.jpg    100%[===================>] 111.61K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:08 (55.8 MB/s) - ‘000000551439.jpg’ saved [114291/114291]
#
# --2022-01-30 05:31:08--  http://images.cocodataset.org/val2017/000000503755.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 98898 (97K) [image/jpeg]
# Saving to: ‘000000503755.jpg’
#
# 000000503755.jpg    100%[===================>]  96.58K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:08 (31.2 MB/s) - ‘000000503755.jpg’ saved [98898/98898]
#
# --2022-01-30 05:31:08--  http://images.cocodataset.org/val2017/000000376093.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 238962 (233K) [image/jpeg]
# Saving to: ‘000000376093.jpg’
#
# 000000376093.jpg    100%[===================>] 233.36K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:08 (83.6 MB/s) - ‘000000376093.jpg’ saved [238962/238962]
#
# --2022-01-30 05:31:08--  http://images.cocodataset.org/val2017/000000491008.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 217966 (213K) [image/jpeg]
# Saving to: ‘000000491008.jpg’
#
# 000000491008.jpg    100%[===================>] 212.86K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:08 (88.2 MB/s) - ‘000000491008.jpg’ saved [217966/217966]
#
# --2022-01-30 05:31:08--  http://images.cocodataset.org/val2017/000000474167.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 114777 (112K) [image/jpeg]
# Saving to: ‘000000474167.jpg’
#
# 000000474167.jpg    100%[===================>] 112.09K  --.-KB/s    in 0.007s
#
# 2022-01-30 05:31:08 (16.7 MB/s) - ‘000000474167.jpg’ saved [114777/114777]
#
# --2022-01-30 05:31:08--  http://images.cocodataset.org/val2017/000000117744.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 157177 (153K) [image/jpeg]
# Saving to: ‘000000117744.jpg’
#
# 000000117744.jpg    100%[===================>] 153.49K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:08 (70.1 MB/s) - ‘000000117744.jpg’ saved [157177/157177]
#
# --2022-01-30 05:31:08--  http://images.cocodataset.org/val2017/000000179487.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 247050 (241K) [image/jpeg]
# Saving to: ‘000000179487.jpg’
#
# 000000179487.jpg    100%[===================>] 241.26K  --.-KB/s    in 0.01s
#
# 2022-01-30 05:31:08 (22.9 MB/s) - ‘000000179487.jpg’ saved [247050/247050]
#
# --2022-01-30 05:31:08--  http://images.cocodataset.org/val2017/000000473237.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 104774 (102K) [image/jpeg]
# Saving to: ‘000000473237.jpg’
#
# 000000473237.jpg    100%[===================>] 102.32K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:08 (45.2 MB/s) - ‘000000473237.jpg’ saved [104774/104774]
#
# --2022-01-30 05:31:08--  http://images.cocodataset.org/val2017/000000203864.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 329379 (322K) [image/jpeg]
# Saving to: ‘000000203864.jpg’
#
# 000000203864.jpg    100%[===================>] 321.66K  --.-KB/s    in 0.02s
#
# 2022-01-30 05:31:08 (12.8 MB/s) - ‘000000203864.jpg’ saved [329379/329379]
#
# --2022-01-30 05:31:08--  http://images.cocodataset.org/val2017/000000532690.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 110520 (108K) [image/jpeg]
# Saving to: ‘000000532690.jpg’
#
# 000000532690.jpg    100%[===================>] 107.93K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:09 (60.8 MB/s) - ‘000000532690.jpg’ saved [110520/110520]
#
# --2022-01-30 05:31:09--  http://images.cocodataset.org/val2017/000000390246.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 191952 (187K) [image/jpeg]
# Saving to: ‘000000390246.jpg’
#
# 000000390246.jpg    100%[===================>] 187.45K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:09 (47.6 MB/s) - ‘000000390246.jpg’ saved [191952/191952]
#
# --2022-01-30 05:31:09--  http://images.cocodataset.org/val2017/000000257865.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 102842 (100K) [image/jpeg]
# Saving to: ‘000000257865.jpg’
#
# 000000257865.jpg    100%[===================>] 100.43K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:09 (24.8 MB/s) - ‘000000257865.jpg’ saved [102842/102842]
#
# --2022-01-30 05:31:09--  http://images.cocodataset.org/val2017/000000372349.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 131262 (128K) [image/jpeg]
# Saving to: ‘000000372349.jpg’
#
# 000000372349.jpg    100%[===================>] 128.19K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:09 (29.7 MB/s) - ‘000000372349.jpg’ saved [131262/131262]
#
# --2022-01-30 05:31:09--  http://images.cocodataset.org/val2017/000000382125.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 183654 (179K) [image/jpeg]
# Saving to: ‘000000382125.jpg’
#
# 000000382125.jpg    100%[===================>] 179.35K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:09 (61.4 MB/s) - ‘000000382125.jpg’ saved [183654/183654]
#
# --2022-01-30 05:31:09--  http://images.cocodataset.org/val2017/000000441286.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 217566 (212K) [image/jpeg]
# Saving to: ‘000000441286.jpg’
#
# 000000441286.jpg    100%[===================>] 212.47K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:09 (60.6 MB/s) - ‘000000441286.jpg’ saved [217566/217566]
#
# --2022-01-30 05:31:09--  http://images.cocodataset.org/val2017/000000547854.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 152428 (149K) [image/jpeg]
# Saving to: ‘000000547854.jpg’
#
# 000000547854.jpg    100%[===================>] 148.86K  --.-KB/s    in 0.09s
#
# 2022-01-30 05:31:09 (1.70 MB/s) - ‘000000547854.jpg’ saved [152428/152428]
#
# --2022-01-30 05:31:09--  http://images.cocodataset.org/val2017/000000556193.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 100115 (98K) [image/jpeg]
# Saving to: ‘000000556193.jpg’
#
# 000000556193.jpg    100%[===================>]  97.77K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:09 (59.8 MB/s) - ‘000000556193.jpg’ saved [100115/100115]
#
# --2022-01-30 05:31:09--  http://images.cocodataset.org/val2017/000000317999.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 118492 (116K) [image/jpeg]
# Saving to: ‘000000317999.jpg’
#
# 000000317999.jpg    100%[===================>] 115.71K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:09 (48.0 MB/s) - ‘000000317999.jpg’ saved [118492/118492]
#
# --2022-01-30 05:31:09--  http://images.cocodataset.org/val2017/000000376206.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 157506 (154K) [image/jpeg]
# Saving to: ‘000000376206.jpg’
#
# 000000376206.jpg    100%[===================>] 153.81K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:10 (36.7 MB/s) - ‘000000376206.jpg’ saved [157506/157506]
#
# --2022-01-30 05:31:10--  http://images.cocodataset.org/val2017/000000382009.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 147805 (144K) [image/jpeg]
# Saving to: ‘000000382009.jpg’
#
# 000000382009.jpg    100%[===================>] 144.34K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:10 (48.7 MB/s) - ‘000000382009.jpg’ saved [147805/147805]
#
# --2022-01-30 05:31:10--  http://images.cocodataset.org/val2017/000000578545.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 189338 (185K) [image/jpeg]
# Saving to: ‘000000578545.jpg’
#
# 000000578545.jpg    100%[===================>] 184.90K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:10 (75.0 MB/s) - ‘000000578545.jpg’ saved [189338/189338]
#
# --2022-01-30 05:31:10--  http://images.cocodataset.org/val2017/000000363207.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 230407 (225K) [image/jpeg]
# Saving to: ‘000000363207.jpg’
#
# 000000363207.jpg    100%[===================>] 225.01K  --.-KB/s    in 0.009s
#
# 2022-01-30 05:31:10 (23.3 MB/s) - ‘000000363207.jpg’ saved [230407/230407]
#
# --2022-01-30 05:31:10--  http://images.cocodataset.org/val2017/000000278973.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 213173 (208K) [image/jpeg]
# Saving to: ‘000000278973.jpg’
#
# 000000278973.jpg    100%[===================>] 208.18K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:10 (57.1 MB/s) - ‘000000278973.jpg’ saved [213173/213173]
#
# --2022-01-30 05:31:10--  http://images.cocodataset.org/val2017/000000355257.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 200812 (196K) [image/jpeg]
# Saving to: ‘000000355257.jpg’
#
# 000000355257.jpg    100%[===================>] 196.11K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:10 (55.3 MB/s) - ‘000000355257.jpg’ saved [200812/200812]
#
# --2022-01-30 05:31:10--  http://images.cocodataset.org/val2017/000000135604.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 243550 (238K) [image/jpeg]
# Saving to: ‘000000135604.jpg’
#
# 000000135604.jpg    100%[===================>] 237.84K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:10 (78.6 MB/s) - ‘000000135604.jpg’ saved [243550/243550]
#
# --2022-01-30 05:31:10--  http://images.cocodataset.org/val2017/000000201072.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 177691 (174K) [image/jpeg]
# Saving to: ‘000000201072.jpg’
#
# 000000201072.jpg    100%[===================>] 173.53K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:10 (76.8 MB/s) - ‘000000201072.jpg’ saved [177691/177691]
#
# --2022-01-30 05:31:10--  http://images.cocodataset.org/val2017/000000404839.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 141077 (138K) [image/jpeg]
# Saving to: ‘000000404839.jpg’
#
# 000000404839.jpg    100%[===================>] 137.77K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:10 (35.0 MB/s) - ‘000000404839.jpg’ saved [141077/141077]
#
# --2022-01-30 05:31:10--  http://images.cocodataset.org/val2017/000000378284.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 176972 (173K) [image/jpeg]
# Saving to: ‘000000378284.jpg’
#
# 000000378284.jpg    100%[===================>] 172.82K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:11 (45.9 MB/s) - ‘000000378284.jpg’ saved [176972/176972]
#
# --2022-01-30 05:31:11--  http://images.cocodataset.org/val2017/000000185890.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 173169 (169K) [image/jpeg]
# Saving to: ‘000000185890.jpg’
#
# 000000185890.jpg    100%[===================>] 169.11K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:11 (62.0 MB/s) - ‘000000185890.jpg’ saved [173169/173169]
#
# --2022-01-30 05:31:11--  http://images.cocodataset.org/val2017/000000402615.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 278636 (272K) [image/jpeg]
# Saving to: ‘000000402615.jpg’
#
# 000000402615.jpg    100%[===================>] 272.11K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:11 (93.1 MB/s) - ‘000000402615.jpg’ saved [278636/278636]
#
# --2022-01-30 05:31:11--  http://images.cocodataset.org/val2017/000000180101.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 230323 (225K) [image/jpeg]
# Saving to: ‘000000180101.jpg’
#
# 000000180101.jpg    100%[===================>] 224.92K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:11 (53.5 MB/s) - ‘000000180101.jpg’ saved [230323/230323]
#
# --2022-01-30 05:31:11--  http://images.cocodataset.org/val2017/000000380711.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 114491 (112K) [image/jpeg]
# Saving to: ‘000000380711.jpg’
#
# 000000380711.jpg    100%[===================>] 111.81K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:11 (34.0 MB/s) - ‘000000380711.jpg’ saved [114491/114491]
#
# --2022-01-30 05:31:11--  http://images.cocodataset.org/val2017/000000571598.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 227926 (223K) [image/jpeg]
# Saving to: ‘000000571598.jpg’
#
# 000000571598.jpg    100%[===================>] 222.58K  --.-KB/s    in 0.005s
#
# 2022-01-30 05:31:11 (41.8 MB/s) - ‘000000571598.jpg’ saved [227926/227926]
#
# --2022-01-30 05:31:11--  http://images.cocodataset.org/val2017/000000378116.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 185180 (181K) [image/jpeg]
# Saving to: ‘000000378116.jpg’
#
# 000000378116.jpg    100%[===================>] 180.84K  --.-KB/s    in 0.02s
#
# 2022-01-30 05:31:11 (8.16 MB/s) - ‘000000378116.jpg’ saved [185180/185180]
#
# --2022-01-30 05:31:11--  http://images.cocodataset.org/val2017/000000497344.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 104380 (102K) [image/jpeg]
# Saving to: ‘000000497344.jpg’
#
# 000000497344.jpg    100%[===================>] 101.93K  --.-KB/s    in 0.001s
#
# 2022-01-30 05:31:11 (68.7 MB/s) - ‘000000497344.jpg’ saved [104380/104380]
#
# --2022-01-30 05:31:11--  http://images.cocodataset.org/val2017/000000179141.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 183313 (179K) [image/jpeg]
# Saving to: ‘000000179141.jpg’
#
# 000000179141.jpg    100%[===================>] 179.02K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:11 (64.2 MB/s) - ‘000000179141.jpg’ saved [183313/183313]
#
# --2022-01-30 05:31:11--  http://images.cocodataset.org/val2017/000000463802.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 116848 (114K) [image/jpeg]
# Saving to: ‘000000463802.jpg’
#
# 000000463802.jpg    100%[===================>] 114.11K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:11 (62.7 MB/s) - ‘000000463802.jpg’ saved [116848/116848]
#
# --2022-01-30 05:31:11--  http://images.cocodataset.org/val2017/000000232692.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 247444 (242K) [image/jpeg]
# Saving to: ‘000000232692.jpg’
#
# 000000232692.jpg    100%[===================>] 241.64K  --.-KB/s    in 0.007s
#
# 2022-01-30 05:31:12 (36.1 MB/s) - ‘000000232692.jpg’ saved [247444/247444]
#
# --2022-01-30 05:31:12--  http://images.cocodataset.org/val2017/000000463918.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 105086 (103K) [image/jpeg]
# Saving to: ‘000000463918.jpg’
#
# 000000463918.jpg    100%[===================>] 102.62K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:12 (61.4 MB/s) - ‘000000463918.jpg’ saved [105086/105086]
#
# --2022-01-30 05:31:12--  http://images.cocodataset.org/val2017/000000127530.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 129112 (126K) [image/jpeg]
# Saving to: ‘000000127530.jpg’
#
# 000000127530.jpg    100%[===================>] 126.09K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:12 (61.0 MB/s) - ‘000000127530.jpg’ saved [129112/129112]
#
# --2022-01-30 05:31:12--  http://images.cocodataset.org/val2017/000000150417.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 218489 (213K) [image/jpeg]
# Saving to: ‘000000150417.jpg’
#
# 000000150417.jpg    100%[===================>] 213.37K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:12 (54.1 MB/s) - ‘000000150417.jpg’ saved [218489/218489]
#
# --2022-01-30 05:31:12--  http://images.cocodataset.org/val2017/000000329455.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 155091 (151K) [image/jpeg]
# Saving to: ‘000000329455.jpg’
#
# 000000329455.jpg    100%[===================>] 151.46K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:12 (71.2 MB/s) - ‘000000329455.jpg’ saved [155091/155091]
#
# --2022-01-30 05:31:12--  http://images.cocodataset.org/val2017/000000445792.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 106053 (104K) [image/jpeg]
# Saving to: ‘000000445792.jpg’
#
# 000000445792.jpg    100%[===================>] 103.57K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:12 (58.0 MB/s) - ‘000000445792.jpg’ saved [106053/106053]
#
# --2022-01-30 05:31:12--  http://images.cocodataset.org/val2017/000000209530.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 115997 (113K) [image/jpeg]
# Saving to: ‘000000209530.jpg’
#
# 000000209530.jpg    100%[===================>] 113.28K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:12 (39.8 MB/s) - ‘000000209530.jpg’ saved [115997/115997]
#
# --2022-01-30 05:31:12--  http://images.cocodataset.org/val2017/000000300341.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 74113 (72K) [image/jpeg]
# Saving to: ‘000000300341.jpg’
#
# 000000300341.jpg    100%[===================>]  72.38K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:12 (26.9 MB/s) - ‘000000300341.jpg’ saved [74113/74113]
#
# --2022-01-30 05:31:12--  http://images.cocodataset.org/val2017/000000254368.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 126235 (123K) [image/jpeg]
# Saving to: ‘000000254368.jpg’
#
# 000000254368.jpg    100%[===================>] 123.28K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:12 (35.9 MB/s) - ‘000000254368.jpg’ saved [126235/126235]
#
# --2022-01-30 05:31:12--  http://images.cocodataset.org/val2017/000000258883.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 123310 (120K) [image/jpeg]
# Saving to: ‘000000258883.jpg’
#
# 000000258883.jpg    100%[===================>] 120.42K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:12 (36.2 MB/s) - ‘000000258883.jpg’ saved [123310/123310]
#
# --2022-01-30 05:31:12--  http://images.cocodataset.org/val2017/000000391722.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 265084 (259K) [image/jpeg]
# Saving to: ‘000000391722.jpg’
#
# 000000391722.jpg    100%[===================>] 258.87K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:13 (63.9 MB/s) - ‘000000391722.jpg’ saved [265084/265084]
#
# --2022-01-30 05:31:13--  http://images.cocodataset.org/val2017/000000515828.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 143588 (140K) [image/jpeg]
# Saving to: ‘000000515828.jpg’
#
# 000000515828.jpg    100%[===================>] 140.22K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:13 (53.8 MB/s) - ‘000000515828.jpg’ saved [143588/143588]
#
# --2022-01-30 05:31:13--  http://images.cocodataset.org/val2017/000000437331.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 229790 (224K) [image/jpeg]
# Saving to: ‘000000437331.jpg’
#
# 000000437331.jpg    100%[===================>] 224.40K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:13 (63.2 MB/s) - ‘000000437331.jpg’ saved [229790/229790]
#
# --2022-01-30 05:31:13--  http://images.cocodataset.org/val2017/000000122962.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 238417 (233K) [image/jpeg]
# Saving to: ‘000000122962.jpg’
#
# 000000122962.jpg    100%[===================>] 232.83K  --.-KB/s    in 0.005s
#
# 2022-01-30 05:31:13 (49.5 MB/s) - ‘000000122962.jpg’ saved [238417/238417]
#
# --2022-01-30 05:31:13--  http://images.cocodataset.org/val2017/000000342128.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 295808 (289K) [image/jpeg]
# Saving to: ‘000000342128.jpg’
#
# 000000342128.jpg    100%[===================>] 288.88K  --.-KB/s    in 0.005s
#
# 2022-01-30 05:31:13 (53.7 MB/s) - ‘000000342128.jpg’ saved [295808/295808]
#
# --2022-01-30 05:31:13--  http://images.cocodataset.org/val2017/000000279541.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 217054 (212K) [image/jpeg]
# Saving to: ‘000000279541.jpg’
#
# 000000279541.jpg    100%[===================>] 211.97K  --.-KB/s    in 0.01s
#
# 2022-01-30 05:31:13 (16.1 MB/s) - ‘000000279541.jpg’ saved [217054/217054]
#
# --2022-01-30 05:31:13--  http://images.cocodataset.org/val2017/000000368212.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 213670 (209K) [image/jpeg]
# Saving to: ‘000000368212.jpg’
#
# 000000368212.jpg    100%[===================>] 208.66K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:13 (84.0 MB/s) - ‘000000368212.jpg’ saved [213670/213670]
#
# --2022-01-30 05:31:13--  http://images.cocodataset.org/val2017/000000485071.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 145457 (142K) [image/jpeg]
# Saving to: ‘000000485071.jpg’
#
# 000000485071.jpg    100%[===================>] 142.05K  --.-KB/s    in 0.006s
#
# 2022-01-30 05:31:13 (24.1 MB/s) - ‘000000485071.jpg’ saved [145457/145457]
#
# --2022-01-30 05:31:13--  http://images.cocodataset.org/val2017/000000172946.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 90920 (89K) [image/jpeg]
# Saving to: ‘000000172946.jpg’
#
# 000000172946.jpg    100%[===================>]  88.79K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:13 (53.4 MB/s) - ‘000000172946.jpg’ saved [90920/90920]
#
# --2022-01-30 05:31:13--  http://images.cocodataset.org/val2017/000000133244.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 163495 (160K) [image/jpeg]
# Saving to: ‘000000133244.jpg’
#
# 000000133244.jpg    100%[===================>] 159.66K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:14 (80.9 MB/s) - ‘000000133244.jpg’ saved [163495/163495]
#
# --2022-01-30 05:31:14--  http://images.cocodataset.org/val2017/000000326248.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 222396 (217K) [image/jpeg]
# Saving to: ‘000000326248.jpg’
#
# 000000326248.jpg    100%[===================>] 217.18K  --.-KB/s    in 0.005s
#
# 2022-01-30 05:31:14 (44.5 MB/s) - ‘000000326248.jpg’ saved [222396/222396]
#
# --2022-01-30 05:31:14--  http://images.cocodataset.org/val2017/000000386879.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 160341 (157K) [image/jpeg]
# Saving to: ‘000000386879.jpg’
#
# 000000386879.jpg    100%[===================>] 156.58K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:14 (36.2 MB/s) - ‘000000386879.jpg’ saved [160341/160341]
#
# --2022-01-30 05:31:14--  http://images.cocodataset.org/val2017/000000474028.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 246520 (241K) [image/jpeg]
# Saving to: ‘000000474028.jpg’
#
# 000000474028.jpg    100%[===================>] 240.74K  --.-KB/s    in 0.005s
#
# 2022-01-30 05:31:14 (44.4 MB/s) - ‘000000474028.jpg’ saved [246520/246520]
#
# --2022-01-30 05:31:14--  http://images.cocodataset.org/val2017/000000409211.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 177265 (173K) [image/jpeg]
# Saving to: ‘000000409211.jpg’
#
# 000000409211.jpg    100%[===================>] 173.11K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:14 (71.2 MB/s) - ‘000000409211.jpg’ saved [177265/177265]
#
# --2022-01-30 05:31:14--  http://images.cocodataset.org/val2017/000000121744.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 212520 (208K) [image/jpeg]
# Saving to: ‘000000121744.jpg’
#
# 000000121744.jpg    100%[===================>] 207.54K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:14 (67.2 MB/s) - ‘000000121744.jpg’ saved [212520/212520]
#
# --2022-01-30 05:31:14--  http://images.cocodataset.org/val2017/000000189775.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 162649 (159K) [image/jpeg]
# Saving to: ‘000000189775.jpg’
#
# 000000189775.jpg    100%[===================>] 158.84K  --.-KB/s    in 0.006s
#
# 2022-01-30 05:31:14 (24.1 MB/s) - ‘000000189775.jpg’ saved [162649/162649]
#
# --2022-01-30 05:31:14--  http://images.cocodataset.org/val2017/000000126137.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 156459 (153K) [image/jpeg]
# Saving to: ‘000000126137.jpg’
#
# 000000126137.jpg    100%[===================>] 152.79K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:14 (42.5 MB/s) - ‘000000126137.jpg’ saved [156459/156459]
#
# --2022-01-30 05:31:14--  http://images.cocodataset.org/val2017/000000479248.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 198998 (194K) [image/jpeg]
# Saving to: ‘000000479248.jpg’
#
# 000000479248.jpg    100%[===================>] 194.33K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:14 (63.3 MB/s) - ‘000000479248.jpg’ saved [198998/198998]
#
# --2022-01-30 05:31:14--  http://images.cocodataset.org/val2017/000000493905.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 273097 (267K) [image/jpeg]
# Saving to: ‘000000493905.jpg’
#
# 000000493905.jpg    100%[===================>] 266.70K  --.-KB/s    in 0.02s
#
# 2022-01-30 05:31:15 (12.0 MB/s) - ‘000000493905.jpg’ saved [273097/273097]
#
# --2022-01-30 05:31:15--  http://images.cocodataset.org/val2017/000000356505.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 194567 (190K) [image/jpeg]
# Saving to: ‘000000356505.jpg’
#
# 000000356505.jpg    100%[===================>] 190.01K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:15 (66.1 MB/s) - ‘000000356505.jpg’ saved [194567/194567]
#
# --2022-01-30 05:31:15--  http://images.cocodataset.org/val2017/000000578489.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 109838 (107K) [image/jpeg]
# Saving to: ‘000000578489.jpg’
#
# 000000578489.jpg    100%[===================>] 107.26K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:15 (62.3 MB/s) - ‘000000578489.jpg’ saved [109838/109838]
#
# --2022-01-30 05:31:15--  http://images.cocodataset.org/val2017/000000551820.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 162441 (159K) [image/jpeg]
# Saving to: ‘000000551820.jpg’
#
# 000000551820.jpg    100%[===================>] 158.63K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:15 (36.2 MB/s) - ‘000000551820.jpg’ saved [162441/162441]
#
# --2022-01-30 05:31:15--  http://images.cocodataset.org/val2017/000000376900.jpg
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.217.203.73|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 202566 (198K) [image/jpeg]
# Saving to: ‘000000376900.jpg’
#
# 000000376900.jpg    100%[===================>] 197.82K  --.-KB/s    in 0.1s
#
# 2022-01-30 05:31:15 (1.68 MB/s) - ‘000000376900.jpg’ saved [202566/202566]
#
# --2022-01-30 05:31:15--  http://images.cocodataset.org/val2017/000000541123.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 243248 (238K) [image/jpeg]
# Saving to: ‘000000541123.jpg’
#
# 000000541123.jpg    100%[===================>] 237.55K  --.-KB/s    in 0.03s
#
# 2022-01-30 05:31:15 (8.23 MB/s) - ‘000000541123.jpg’ saved [243248/243248]
#
# --2022-01-30 05:31:15--  http://images.cocodataset.org/val2017/000000179642.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 232374 (227K) [image/jpeg]
# Saving to: ‘000000179642.jpg’
#
# 000000179642.jpg    100%[===================>] 226.93K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:15 (72.5 MB/s) - ‘000000179642.jpg’ saved [232374/232374]
#
# --2022-01-30 05:31:15--  http://images.cocodataset.org/val2017/000000157046.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 149418 (146K) [image/jpeg]
# Saving to: ‘000000157046.jpg’
#
# 000000157046.jpg    100%[===================>] 145.92K  --.-KB/s    in 0.006s
#
# 2022-01-30 05:31:16 (24.9 MB/s) - ‘000000157046.jpg’ saved [149418/149418]
#
# --2022-01-30 05:31:16--  http://images.cocodataset.org/val2017/000000398203.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 228579 (223K) [image/jpeg]
# Saving to: ‘000000398203.jpg’
#
# 000000398203.jpg    100%[===================>] 223.22K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:16 (52.6 MB/s) - ‘000000398203.jpg’ saved [228579/228579]
#
# --2022-01-30 05:31:16--  http://images.cocodataset.org/val2017/000000386352.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 151173 (148K) [image/jpeg]
# Saving to: ‘000000386352.jpg’
#
# 000000386352.jpg    100%[===================>] 147.63K  --.-KB/s    in 0.007s
#
# ...
#
# --2022-01-30 05:31:54--  http://images.cocodataset.org/val2017/000000433980.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 180853 (177K) [image/jpeg]
# Saving to: ‘000000433980.jpg’
#
# 000000433980.jpg    100%[===================>] 176.61K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:54 (71.6 MB/s) - ‘000000433980.jpg’ saved [180853/180853]
#
# --2022-01-30 05:31:54--  http://images.cocodataset.org/val2017/000000368752.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 189704 (185K) [image/jpeg]
# Saving to: ‘000000368752.jpg’
#
# 000000368752.jpg    100%[===================>] 185.26K  --.-KB/s    in 0.02s
#
# 2022-01-30 05:31:55 (9.02 MB/s) - ‘000000368752.jpg’ saved [189704/189704]
#
# --2022-01-30 05:31:55--  http://images.cocodataset.org/val2017/000000137294.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 180478 (176K) [image/jpeg]
# Saving to: ‘000000137294.jpg’
#
# 000000137294.jpg    100%[===================>] 176.25K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:55 (39.5 MB/s) - ‘000000137294.jpg’ saved [180478/180478]
#
# --2022-01-30 05:31:55--  http://images.cocodataset.org/val2017/000000156292.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 261052 (255K) [image/jpeg]
# Saving to: ‘000000156292.jpg’
#
# 000000156292.jpg    100%[===================>] 254.93K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:55 (73.2 MB/s) - ‘000000156292.jpg’ saved [261052/261052]
#
# --2022-01-30 05:31:55--  http://images.cocodataset.org/val2017/000000224807.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 207818 (203K) [image/jpeg]
# Saving to: ‘000000224807.jpg’
#
# 000000224807.jpg    100%[===================>] 202.95K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:55 (68.4 MB/s) - ‘000000224807.jpg’ saved [207818/207818]
#
# --2022-01-30 05:31:55--  http://images.cocodataset.org/val2017/000000151820.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 162172 (158K) [image/jpeg]
# Saving to: ‘000000151820.jpg’
#
# 000000151820.jpg    100%[===================>] 158.37K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:55 (74.6 MB/s) - ‘000000151820.jpg’ saved [162172/162172]
#
# --2022-01-30 05:31:55--  http://images.cocodataset.org/val2017/000000381587.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 223461 (218K) [image/jpeg]
# Saving to: ‘000000381587.jpg’
#
# 000000381587.jpg    100%[===================>] 218.22K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:55 (66.2 MB/s) - ‘000000381587.jpg’ saved [223461/223461]
#
# --2022-01-30 05:31:55--  http://images.cocodataset.org/val2017/000000338905.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 83033 (81K) [image/jpeg]
# Saving to: ‘000000338905.jpg’
#
# 000000338905.jpg    100%[===================>]  81.09K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:55 (48.0 MB/s) - ‘000000338905.jpg’ saved [83033/83033]
#
# --2022-01-30 05:31:55--  http://images.cocodataset.org/val2017/000000484351.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 217452 (212K) [image/jpeg]
# Saving to: ‘000000484351.jpg’
#
# 000000484351.jpg    100%[===================>] 212.36K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:55 (82.3 MB/s) - ‘000000484351.jpg’ saved [217452/217452]
#
# --2022-01-30 05:31:55--  http://images.cocodataset.org/val2017/000000203629.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 98894 (97K) [image/jpeg]
# Saving to: ‘000000203629.jpg’
#
# 000000203629.jpg    100%[===================>]  96.58K  --.-KB/s    in 0.02s
#
# 2022-01-30 05:31:56 (4.64 MB/s) - ‘000000203629.jpg’ saved [98894/98894]
#
# --2022-01-30 05:31:56--  http://images.cocodataset.org/val2017/000000282298.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 279497 (273K) [image/jpeg]
# Saving to: ‘000000282298.jpg’
#
# 000000282298.jpg    100%[===================>] 272.95K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:56 (72.3 MB/s) - ‘000000282298.jpg’ saved [279497/279497]
#
# --2022-01-30 05:31:56--  http://images.cocodataset.org/val2017/000000257169.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 125805 (123K) [image/jpeg]
# Saving to: ‘000000257169.jpg’
#
# 000000257169.jpg    100%[===================>] 122.86K  --.-KB/s    in 0.007s
#
# 2022-01-30 05:31:56 (17.1 MB/s) - ‘000000257169.jpg’ saved [125805/125805]
#
# --2022-01-30 05:31:56--  http://images.cocodataset.org/val2017/000000424135.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 199629 (195K) [image/jpeg]
# Saving to: ‘000000424135.jpg’
#
# 000000424135.jpg    100%[===================>] 194.95K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:56 (42.8 MB/s) - ‘000000424135.jpg’ saved [199629/199629]
#
# --2022-01-30 05:31:56--  http://images.cocodataset.org/val2017/000000305609.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 177554 (173K) [image/jpeg]
# Saving to: ‘000000305609.jpg’
#
# 000000305609.jpg    100%[===================>] 173.39K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:56 (66.4 MB/s) - ‘000000305609.jpg’ saved [177554/177554]
#
# --2022-01-30 05:31:56--  http://images.cocodataset.org/val2017/000000363188.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 255569 (250K) [image/jpeg]
# Saving to: ‘000000363188.jpg’
#
# 000000363188.jpg    100%[===================>] 249.58K  --.-KB/s    in 0.005s
#
# 2022-01-30 05:31:56 (47.7 MB/s) - ‘000000363188.jpg’ saved [255569/255569]
#
# --2022-01-30 05:31:56--  http://images.cocodataset.org/val2017/000000142620.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 267317 (261K) [image/jpeg]
# Saving to: ‘000000142620.jpg’
#
# 000000142620.jpg    100%[===================>] 261.05K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:56 (89.6 MB/s) - ‘000000142620.jpg’ saved [267317/267317]
#
# --2022-01-30 05:31:56--  http://images.cocodataset.org/val2017/000000475572.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 92212 (90K) [image/jpeg]
# Saving to: ‘000000475572.jpg’
#
# 000000475572.jpg    100%[===================>]  90.05K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:56 (45.5 MB/s) - ‘000000475572.jpg’ saved [92212/92212]
#
# --2022-01-30 05:31:56--  http://images.cocodataset.org/val2017/000000376322.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 199801 (195K) [image/jpeg]
# Saving to: ‘000000376322.jpg’
#
# 000000376322.jpg    100%[===================>] 195.12K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:56 (94.6 MB/s) - ‘000000376322.jpg’ saved [199801/199801]
#
# --2022-01-30 05:31:56--  http://images.cocodataset.org/val2017/000000388927.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 85887 (84K) [image/jpeg]
# Saving to: ‘000000388927.jpg’
#
# 000000388927.jpg    100%[===================>]  83.87K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:56 (25.0 MB/s) - ‘000000388927.jpg’ saved [85887/85887]
#
# --2022-01-30 05:31:56--  http://images.cocodataset.org/val2017/000000399205.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 201390 (197K) [image/jpeg]
# Saving to: ‘000000399205.jpg’
#
# 000000399205.jpg    100%[===================>] 196.67K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:57 (69.4 MB/s) - ‘000000399205.jpg’ saved [201390/201390]
#
# --2022-01-30 05:31:57--  http://images.cocodataset.org/val2017/000000314264.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 173740 (170K) [image/jpeg]
# Saving to: ‘000000314264.jpg’
#
# 000000314264.jpg    100%[===================>] 169.67K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:57 (47.3 MB/s) - ‘000000314264.jpg’ saved [173740/173740]
#
# --2022-01-30 05:31:57--  http://images.cocodataset.org/val2017/000000321333.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 136617 (133K) [image/jpeg]
# Saving to: ‘000000321333.jpg’
#
# 000000321333.jpg    100%[===================>] 133.42K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:57 (42.8 MB/s) - ‘000000321333.jpg’ saved [136617/136617]
#
# --2022-01-30 05:31:57--  http://images.cocodataset.org/val2017/000000233238.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 214363 (209K) [image/jpeg]
# Saving to: ‘000000233238.jpg’
#
# 000000233238.jpg    100%[===================>] 209.34K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:57 (55.7 MB/s) - ‘000000233238.jpg’ saved [214363/214363]
#
# --2022-01-30 05:31:57--  http://images.cocodataset.org/val2017/000000546219.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 220256 (215K) [image/jpeg]
# Saving to: ‘000000546219.jpg’
#
# 000000546219.jpg    100%[===================>] 215.09K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:57 (50.0 MB/s) - ‘000000546219.jpg’ saved [220256/220256]
#
# --2022-01-30 05:31:57--  http://images.cocodataset.org/val2017/000000171190.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 112108 (109K) [image/jpeg]
# Saving to: ‘000000171190.jpg’
#
# 000000171190.jpg    100%[===================>] 109.48K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:57 (35.6 MB/s) - ‘000000171190.jpg’ saved [112108/112108]
#
# --2022-01-30 05:31:57--  http://images.cocodataset.org/val2017/000000117492.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 274606 (268K) [image/jpeg]
# Saving to: ‘000000117492.jpg’
#
# 000000117492.jpg    100%[===================>] 268.17K  --.-KB/s    in 0.005s
#
# 2022-01-30 05:31:57 (54.0 MB/s) - ‘000000117492.jpg’ saved [274606/274606]
#
# --2022-01-30 05:31:57--  http://images.cocodataset.org/val2017/000000166918.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 219406 (214K) [image/jpeg]
# Saving to: ‘000000166918.jpg’
#
# 000000166918.jpg    100%[===================>] 214.26K  --.-KB/s    in 0.01s
#
# 2022-01-30 05:31:57 (18.2 MB/s) - ‘000000166918.jpg’ saved [219406/219406]
#
# --2022-01-30 05:31:57--  http://images.cocodataset.org/val2017/000000436617.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 183281 (179K) [image/jpeg]
# Saving to: ‘000000436617.jpg’
#
# 000000436617.jpg    100%[===================>] 178.99K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:57 (42.8 MB/s) - ‘000000436617.jpg’ saved [183281/183281]
#
# --2022-01-30 05:31:57--  http://images.cocodataset.org/val2017/000000332570.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 100045 (98K) [image/jpeg]
# Saving to: ‘000000332570.jpg’
#
# 000000332570.jpg    100%[===================>]  97.70K  --.-KB/s    in 0.005s
#
# 2022-01-30 05:31:58 (19.8 MB/s) - ‘000000332570.jpg’ saved [100045/100045]
#
# --2022-01-30 05:31:58--  http://images.cocodataset.org/val2017/000000311180.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 105228 (103K) [image/jpeg]
# Saving to: ‘000000311180.jpg’
#
# 000000311180.jpg    100%[===================>] 102.76K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:58 (29.1 MB/s) - ‘000000311180.jpg’ saved [105228/105228]
#
# --2022-01-30 05:31:58--  http://images.cocodataset.org/val2017/000000263425.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 268451 (262K) [image/jpeg]
# Saving to: ‘000000263425.jpg’
#
# 000000263425.jpg    100%[===================>] 262.16K  --.-KB/s    in 0.007s
#
# 2022-01-30 05:31:58 (37.8 MB/s) - ‘000000263425.jpg’ saved [268451/268451]
#
# --2022-01-30 05:31:58--  http://images.cocodataset.org/val2017/000000292488.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 44116 (43K) [image/jpeg]
# Saving to: ‘000000292488.jpg’
#
# 000000292488.jpg    100%[===================>]  43.08K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:58 (13.9 MB/s) - ‘000000292488.jpg’ saved [44116/44116]
#
# --2022-01-30 05:31:58--  http://images.cocodataset.org/val2017/000000500716.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 134403 (131K) [image/jpeg]
# Saving to: ‘000000500716.jpg’
#
# 000000500716.jpg    100%[===================>] 131.25K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:58 (34.7 MB/s) - ‘000000500716.jpg’ saved [134403/134403]
#
# --2022-01-30 05:31:58--  http://images.cocodataset.org/val2017/000000552775.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 133107 (130K) [image/jpeg]
# Saving to: ‘000000552775.jpg’
#
# 000000552775.jpg    100%[===================>] 129.99K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:58 (73.8 MB/s) - ‘000000552775.jpg’ saved [133107/133107]
#
# --2022-01-30 05:31:58--  http://images.cocodataset.org/val2017/000000546475.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 205319 (201K) [image/jpeg]
# Saving to: ‘000000546475.jpg’
#
# 000000546475.jpg    100%[===================>] 200.51K  --.-KB/s    in 0.004s
#
# 2022-01-30 05:31:58 (46.0 MB/s) - ‘000000546475.jpg’ saved [205319/205319]
#
# --2022-01-30 05:31:58--  http://images.cocodataset.org/val2017/000000435205.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 89430 (87K) [image/jpeg]
# Saving to: ‘000000435205.jpg’
#
# 000000435205.jpg    100%[===================>]  87.33K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:58 (46.3 MB/s) - ‘000000435205.jpg’ saved [89430/89430]
#
# --2022-01-30 05:31:58--  http://images.cocodataset.org/val2017/000000351096.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 104555 (102K) [image/jpeg]
# Saving to: ‘000000351096.jpg’
#
# 000000351096.jpg    100%[===================>] 102.10K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:58 (65.9 MB/s) - ‘000000351096.jpg’ saved [104555/104555]
#
# --2022-01-30 05:31:58--  http://images.cocodataset.org/val2017/000000251824.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 155684 (152K) [image/jpeg]
# Saving to: ‘000000251824.jpg’
#
# 000000251824.jpg    100%[===================>] 152.04K  --.-KB/s    in 0.003s
#
# 2022-01-30 05:31:58 (45.2 MB/s) - ‘000000251824.jpg’ saved [155684/155684]
#
# --2022-01-30 05:31:58--  http://images.cocodataset.org/val2017/000000394940.jpg
# Reusing existing connection to images.cocodataset.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 158150 (154K) [image/jpeg]
# Saving to: ‘000000394940.jpg’
#
# 000000394940.jpg    100%[===================>] 154.44K  --.-KB/s    in 0.002s
#
# 2022-01-30 05:31:59 (72.7 MB/s) - ‘000000394940.jpg’ saved [158150/158150]
#
# FINISHED --2022-01-30 05:31:59--
# Total wall clock time: 3m 18s
# Downloaded: 1788 files, 276M in 11s (26.2 MB/s)

# %%
# len(os.listdir("/content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data/person train images"))
# Out:
# 43152

# %%
# len(os.listdir('/content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data/person cv images'))
# Out:
# 1788

# %%
def create_gt_heatmap_labels(img,annotations,resize_shape=(64,48)):

  gt_heatmap = np.zeros(shape=(17,resize_shape[0],resize_shape[1]))
  keypoints = np.array(annotations[img]["keypoints"]).reshape(17,3)
  xmin,ymin,w,h = annotations[img]["bbox"]
  bbox_offset = np.array([xmin,ymin,0])
  bbox_dims = np.array([w,h,1])
  gt_heatmap_dims = np.array([resize_shape[1],resize_shape[0],1])
  keypoints = np.round((keypoints - bbox_offset)*gt_heatmap_dims/bbox_dims).astype(int)

  for i in range(17):

    if keypoints[i,2] > 0:
      y = keypoints[i,0]      
      x = keypoints[i,1]

      if x < 0 or y < 0 or x >= resize_shape[0] or y >= resize_shape[1]:
        keypoints[i,2] = 0.0
        continue

      gt_heatmap[i,x,y] = 1.0
      gt_heatmap[i,:,:] = gaussian_filter(input=gt_heatmap[i,:,:],sigma=2,mode="constant",cval=0.0)
      gt_heatmap[i,:,:] = gt_heatmap[i,:,:]/np.max(gt_heatmap[i,:,:])

  gt_validity = keypoints[:,2] > 0
  gt_validity = gt_validity.reshape(gt_validity.shape[0],1,1)

  return gt_heatmap.astype(float), gt_validity.astype(float)

# %% [markdown]
# # generating training images

# %%
from PIL import Image

# %%
def train_generator(train_images,annotations,batch_size=32,resize_shape=(256,192)):

  num_train_images = len(train_images)
  train_images = np.array(train_images)
  img_norm_mean = np.array([0.485,0.456,0.456])
  img_norm_std = np.array([0.229,0.224,0.225])

  while True:

    for offset in range(0,num_train_images,batch_size):
      
      batch_images = list(np.random.choice(train_images,size=batch_size,replace=False))
      images_batch = []
      gt_heatmaps_batch = []
      gt_validities_batch = []

      for img in batch_images:

        try:
          image = Image.open(os.path.join("/content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data/person train images",img))
          xmin,ymin,w,h = annotations[img]["bbox"]
          cropped_image = image.resize(size=(resize_shape[1],resize_shape[0]),box=(xmin,ymin,xmin+w,ymin+h))   #this will only select the boxed area of the a given image
          cropped_image = np.array(cropped_image)

          if len(cropped_image.shape) != 3:         
            cropped_image = np.stack((cropped_image,)*3,axis=-1)

          cropped_image = cropped_image.astype(float)/255.0
          cropped_image = (cropped_image - img_norm_mean)/img_norm_std

          cropped_image = cropped_image.reshape(resize_shape[0],resize_shape[1],3)    
          images_batch.append(cropped_image)

          gt_heatmap,gt_validity = create_gt_heatmap_labels(img,annotations)
          gt_heatmaps_batch.append(gt_heatmap)
          gt_validities_batch.append(gt_validity)

        except UnidentifiedImageError as err:
          continue

      images_batch = np.array(images_batch)
      gt_heatmaps_batch = np.array(gt_heatmaps_batch)
      gt_validities_batch = np.array(gt_validities_batch)

      yield images_batch,gt_heatmaps_batch,gt_validities_batch

# %% [markdown]
# # generating cv images

# %%
def cv_generator(cv_images,annotations,batch_size=298,resize_shape=(256,192)):

  num_cv_train_images = len(cv_images)
  img_norm_mean = np.array([0.485,0.456,0.456])
  img_norm_std = np.array([0.229,0.224,0.225])

  while True:

    for offset in range(0,num_cv_train_images,batch_size):
      
      batch_images = list(np.random.choice(cv_images,size=batch_size,replace=False))
      images_batch = []
      gt_heatmaps_batch = []
      gt_validities_batch = []

      for img in batch_images:

        try:
          image = Image.open(os.path.join("/content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data/person cv images",img))
          xmin,ymin,w,h = annotations[img]["bbox"]
          cropped_image = image.resize(size=(resize_shape[1],resize_shape[0]),box=(xmin,ymin,xmin+w,ymin+h))   #this will only select the boxed area of the a given image
          cropped_image = np.array(cropped_image)

          if len(cropped_image.shape) != 3:
            cropped_image = np.stack((cropped_image,)*3,axis=-1)

          cropped_image = cropped_image.astype(float)/255.0
          cropped_image = (cropped_image - img_norm_mean)/img_norm_std

          cropped_image = cropped_image.reshape(resize_shape[0],resize_shape[1],3)
          images_batch.append(cropped_image)

          gt_heatmap,gt_validity = create_gt_heatmap_labels(img,annotations)
          gt_heatmaps_batch.append(gt_heatmap)
          gt_validities_batch.append(gt_validity)

        except UnidentifiedImageError as err:
          continue

      images_batch = np.array(images_batch)
      gt_heatmaps_batch = np.array(gt_heatmaps_batch)
      gt_validities_batch = np.array(gt_validities_batch)

      yield images_batch,gt_heatmaps_batch,gt_validities_batch

# %% [markdown]
# # trash code for resnet

# %%
def create_pretrained_pose_resnet(resize_shape=(64,48)):

  images_batch = Input(shape=(256,192,3))
  pretrained_resnet = resnet_v2.ResNet50V2(include_top=False,input_shape=(256,192,3))

  pretrained_resnet.trainable = False

  pretrained_resnet_output = pretrained_resnet(images_batch,training=False)
  
  pretrained_resnet_out = Conv2DTranspose(filters=256,kernel_size=4,strides=2,padding="same",
                                          kernel_initializer=random_normal(stddev=0.001))(pretrained_resnet_output)
  pretrained_resnet_out = BatchNormalization()(pretrained_resnet_out)
  pretrained_resnet_out = ReLU()(pretrained_resnet_out)

  pretrained_resnet_out = Conv2DTranspose(filters=256,kernel_size=4,strides=2,padding="same",
                                          kernel_initializer=random_normal(stddev=0.001))(pretrained_resnet_out)
  pretrained_resnet_out = BatchNormalization()(pretrained_resnet_out)
  pretrained_resnet_out = ReLU()(pretrained_resnet_out)

  pretrained_resnet_out = Conv2DTranspose(filters=256,kernel_size=4,strides=2,padding="same",
                                          kernel_initializer=random_normal(stddev=0.001))(pretrained_resnet_out)
  pretrained_resnet_out = BatchNormalization()(pretrained_resnet_out)
  pretrained_resnet_out = ReLU()(pretrained_resnet_out)

  pretrained_resnet_out = Conv2D(filters=17,kernel_size=1,kernel_initializer=random_normal(stddev=0.001))(pretrained_resnet_out)

  pretrained_resnet_out = Reshape((17,resize_shape[0],resize_shape[1]))(pretrained_resnet_out)

  pretrained_pose_resnet = Model(images_batch,pretrained_resnet_out)

  return pretrained_pose_resnet

# %%
mse_loss_fn = tf.keras.losses.MeanSquaredError()

# %%
def mse_loss(heatmap_pred,heatmap_train,heatmap_val_train):

  heatmap_pred = heatmap_val_train * tf.cast(heatmap_pred,tf.float64)
  heatmap_train = heatmap_val_train * heatmap_train
  mse = mse_loss_fn(y_true=heatmap_train,y_pred=tf.cast(heatmap_pred,tf.float64))
  return mse

# %%
pose_estimate_optimizer = keras.optimizers.adam_v2.Adam(learning_rate=0.00001)

# %%
pose_estimate_finetune_optimizer = keras.optimizers.adam_v2.Adam(learning_rate=0.0000001)

# %%
pretrained_pose_resnet = create_pretrained_pose_resnet()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94674944/94668760 [==============================] - 1s 0us/step
# 94683136/94668760 [==============================] - 1s 0us/step

# %%
pretrained_pose_resnet.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 192, 3)]     0
#
#  resnet50v2 (Functional)     (None, 8, 6, 2048)        23564800
#
#  conv2d_transpose (Conv2DTra  (None, 16, 12, 256)      8388864
#  nspose)
#
#  batch_normalization (BatchN  (None, 16, 12, 256)      1024
#  ormalization)
#
#  re_lu (ReLU)                (None, 16, 12, 256)       0
#
#  conv2d_transpose_1 (Conv2DT  (None, 32, 24, 256)      1048832
#  ranspose)
#
#  batch_normalization_1 (Batc  (None, 32, 24, 256)      1024
#  hNormalization)
#
#  re_lu_1 (ReLU)              (None, 32, 24, 256)       0
#
#  conv2d_transpose_2 (Conv2DT  (None, 64, 48, 256)      1048832
#  ranspose)
#
#  batch_normalization_2 (Batc  (None, 64, 48, 256)      1024
#  hNormalization)
#
#  re_lu_2 (ReLU)              (None, 64, 48, 256)       0
#
#  conv2d (Conv2D)             (None, 64, 48, 17)        4369
#
#  reshape (Reshape)           (None, 17, 64, 48)        0
#
# =================================================================
# Total params: 34,058,769
# Trainable params: 10,492,433
# Non-trainable params: 23,566,336
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model=pretrained_pose_resnet,show_shapes=True)

# %%
cd /content/drive/MyDrive/'Human Pose Estimation'
# Out:
# /content/drive/MyDrive/Human Pose Estimation

# %%
pose_estimate_checkpoint_dir = "/content/drive/MyDrive/pose_estimate_checkpoints"
checkpoint_prefix = os.path.join(pose_estimate_checkpoint_dir,"ckpt")
checkpoint = tf.train.Checkpoint(optimizer=pose_estimate_optimizer,model=pretrained_pose_resnet)

# %%
@tf.function
def train_step(images_batch,heatmap_train_batch,heatmap_val_batch):

    with tf.GradientTape() as pose_estimate_tape:
      
      pretrained_pose_resnet.trainable = True
      global heatmap_pred_batch
      heatmap_pred_batch = pretrained_pose_resnet(images_batch,training=True)
      global pose_estimate_loss
      pose_estimate_loss = mse_loss(heatmap_pred=heatmap_pred_batch,heatmap_train=heatmap_train_batch,heatmap_val_train=heatmap_val_batch)
      pose_estimate_gradients = pose_estimate_tape.gradient(pose_estimate_loss, pretrained_pose_resnet.trainable_variables)
      pose_estimate_optimizer.apply_gradients(zip(pose_estimate_gradients, pretrained_pose_resnet.trainable_variables))
     
    return heatmap_pred_batch,pose_estimate_loss

# %%
@tf.function
def cv_step(cv_images_batch,cv_heatmap_train_batch,cv_heatmap_val_batch):

  pretrained_pose_resnet.trainable = True
      
  cv_heatmap_pred_batch = pretrained_pose_resnet(cv_images_batch,training=False)

  pose_estimate_cv_loss = mse_loss(heatmap_pred=cv_heatmap_pred_batch,heatmap_train=cv_heatmap_train_batch,
                                  heatmap_val_train=cv_heatmap_val_batch)

  return cv_heatmap_pred_batch,pose_estimate_cv_loss

# %%
epochs = 90
batch_size = 62
cv_batch_size = 149

# %%
# ORIGINAL FROM HERE:
# https://github.com/microsoft/human-pose-estimation.pytorch/blob/715d29e55f59ae555116542e85ed7175d57120e6/lib/core/evaluate.py
# ------------------------------------------------------------------------------
# Copyright (c) Microsoft
# Licensed under the MIT License.
# Written by Bin Xiao (Bin.Xiao@microsoft.com)
# ------------------------------------------------------------------------------
# Calculates Percentage of Correct Key-points (PCK) accuracy
# A detected joint is considered correct if the distance between the predicted 
# and the true joint is within a certain threshold.


def get_max_preds(batch_heatmaps):
    '''
    get predictions from score maps
    heatmaps: numpy.ndarray([batch_size, num_joints, height, width])
    '''
            
    assert isinstance(batch_heatmaps, np.ndarray), 'batch_heatmaps should be numpy.ndarray'
    assert batch_heatmaps.ndim == 4, 'batch_images should be 4-ndim'
          
    batch_size = batch_heatmaps.shape[0]
    num_joints = batch_heatmaps.shape[1]
    width = batch_heatmaps.shape[3]
    heatmaps_reshaped = batch_heatmaps.reshape((batch_size, num_joints, -1))      # new shape will be (batch_size,number_os_keypoints,height*widht)
    idx = np.argmax(heatmaps_reshaped, 2)                                         # we will return index of maximum value accros 3rd dimemsion
    maxvals = np.amax(heatmaps_reshaped, 2)                                       # this will return maximum values

    maxvals = maxvals.reshape((batch_size, num_joints, 1))                        # adding one more dimension to maximum values and index
    idx = idx.reshape((batch_size, num_joints, 1))

    preds = np.tile(idx, (1, 1, 2)).astype(np.float32)

    preds[:, :, 0] = (preds[:, :, 0]) % width
    preds[:, :, 1] = np.floor((preds[:, :, 1]) / width)

    pred_mask = np.tile(np.greater(maxvals, 0.0), (1, 1, 2))
    pred_mask = pred_mask.astype(np.float32)

    preds *= pred_mask
    return preds, maxvals

# %%
def calc_dists(preds, target, normalize):
    preds = preds.astype(np.float32)
    target = target.astype(np.float32)
    dists = np.zeros((preds.shape[1], preds.shape[0]))
    for n in range(preds.shape[0]):
        for c in range(preds.shape[1]):
            if target[n, c, 0] > 1 and target[n, c, 1] > 1:
                normed_preds = preds[n, c, :] / normalize[n]
                normed_targets = target[n, c, :] / normalize[n]
                dists[c, n] = np.linalg.norm(normed_preds - normed_targets)
            else:
                dists[c, n] = -1
    return dists

# %%
def dist_acc(dists, thr=0.5):
    ''' Return percentage below threshold while ignoring values with a -1 '''
    dist_cal = np.not_equal(dists, -1)
    num_dist_cal = dist_cal.sum()
    if num_dist_cal > 0:
        return np.less(dists[dist_cal], thr).sum() * 1.0 / num_dist_cal
    else:
        return -1

# %%
def accuracy(output, target, hm_type='gaussian', thr=0.5):
    '''
    Calculate accuracy according to PCK,
    but uses ground truth heatmap rather than x,y locations
    First value to be returned is average accuracy across 'idxs',
    followed by individual accuracies
    '''
    idx = list(range(output.shape[1]))
    norm = 1.0
    if hm_type == 'gaussian':
        pred, _ = get_max_preds(output.numpy())
        target, _ = get_max_preds(target)
        h = output.shape[2]
        w = output.shape[3]
        norm = np.ones((pred.shape[0], 2)) * np.array([h, w]) / 10
    dists = calc_dists(pred, target, norm)

    acc = np.zeros((len(idx) + 1))
    avg_acc = 0
    cnt = 0

    for i in range(len(idx)):
        acc[i + 1] = dist_acc(dists[idx[i]],thr=thr)
        if acc[i + 1] >= 0:
            avg_acc = avg_acc + acc[i + 1]
            cnt += 1

    avg_acc = avg_acc / cnt if cnt != 0 else 0
    if cnt != 0:
        acc[0] = avg_acc
    return avg_acc

# %%
class pck_accuracy_metric(keras.metrics.Metric):

  def __init__(self,name="pck_accuracy",**kwargs):
    super().__init__(name=name,**kwargs)
    self.pck_avg_accuracy_sum = self.add_weight(name="pck_avg_accuracy_sum",initializer="zeros",dtype="float32")
    self.total_batches = self.add_weight(name="total_batches",initializer="zeros",dtype="int32")

  def update_state(self,y_true,y_pred,sample_weight=None):
    pck_avg_accuracy = accuracy(output=y_pred,target=y_true,thr=0.5)
    self.pck_avg_accuracy_sum.assign_add(pck_avg_accuracy)
    self.total_batches.assign_add(1)

  def result(self):
    return self.pck_avg_accuracy_sum/tf.cast(self.total_batches,tf.float32)

  def reset_state(self):
    self.pck_avg_accuracy_sum.assign(0.0)
    self.total_batches.assign(0)

# %%
pose_train_acc_metric = pck_accuracy_metric()
pose_val_acc_metric = pck_accuracy_metric()

# %%
pwd
# Out:
# '/content/drive/MyDrive/Human Pose Estimation'

# %%
cd /content/drive/MyDrive/'Human Pose Estimation'/'Human Pose Estimation Data'/annotations
# Out:
# /content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data/annotations

# %%
# json_string = json.dumps(training_annotations)
# json_file_handle = open("training_annotations.json","w")
# json_file_handle.write(json_string)
# json_file_handle.close()

# %%
# json_string = json.dumps(cv_annotations)
# json_file_handle = open("cv_annotations.json","w")
# json_file_handle.write(json_string)
# json_file_handle.close()

# %%
import json

# %%
json_file_handle = open("/content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data/annotations/training_annotations.json")
json_string = json_file_handle.read()
training_annotations = json.loads(json_string)

# %%
json_file_handle = open("/content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data/annotations/cv_annotations.json")
json_string = json_file_handle.read()
cv_annotations = json.loads(json_string)

# %%
cv_images = os.listdir("/content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data/person cv images")

# %%
cv_image_batch,cv_gt_heatmaps_batch,cv_gt_validities_batch = next(cv_generator(cv_images,cv_annotations))

# %%
# cv_image_batch.shape

# %%
# cv_gt_heatmaps_batch.shape

# %%
def train(epochs):
  # global train_images
  train_images = os.listdir("/content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data/person train images")
  # cv_images = os.listdir("/content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data/person cv images")
  # cv_image_batch,cv_gt_heatmaps_batch,cv_gt_validities_batch = cv_generator(cv_images,cv_annotations,batch_size=cv_batch_size)


  for epoch in range(epochs):

    time_step = 1


    for images_batch,gt_heatmaps_batch,gt_validities_batch in train_generator(train_images,
                                                                              training_annotations,batch_size):
      
      with tf.GradientTape() as pose_estimate_tape:
        
        pretrained_pose_resnet.trainable = True
        
        heatmap_pred_batch = pretrained_pose_resnet(images_batch,training=True)
        
        pose_estimate_loss = mse_loss(heatmap_pred=heatmap_pred_batch,heatmap_train=gt_heatmaps_batch,heatmap_val_train=gt_validities_batch)
       
        pose_estimate_gradients = pose_estimate_tape.gradient(pose_estimate_loss, pretrained_pose_resnet.trainable_variables)
 
        pose_estimate_optimizer.apply_gradients(zip(pose_estimate_gradients, pretrained_pose_resnet.trainable_variables))



      print(f' pose estimation loss on epoch {epoch+1} timestep {time_step} is {pose_estimate_loss} ')
      if time_step > len(os.listdir("/content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data/person train images"))//batch_size:
        break

      if time_step % 20 == 0:
        pose_train_acc_metric.update_state(gt_heatmaps_batch,heatmap_pred_batch)
        training_pck_accuracy = pose_train_acc_metric.result()

        cv_heatmap_pred_batch,pose_estimate_cv_loss = cv_step(cv_image_batch,cv_gt_heatmaps_batch,cv_gt_validities_batch)
        pose_val_acc_metric.update_state(cv_gt_heatmaps_batch,cv_heatmap_pred_batch)
        cv_pck_accuracy = pose_val_acc_metric.result()
        print("Epoch: {} Time Step: {} Training Loss: {} Training Accuracy: {} Val Loss: {} Val Accuracy: {}".format(epoch+1,time_step,float(pose_estimate_loss),
                                                                                                              float(training_pck_accuracy),
                                                                                                              float(pose_estimate_cv_loss),
                                                                                                              float(cv_pck_accuracy)))
        
        
        pose_train_acc_metric.reset_state()
        pose_val_acc_metric.reset_state()

      
      time_step = time_step + 1

    checkpoint.save(file_prefix = checkpoint_prefix)

# %%
# !ls '/content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data/person train images' | grep '000000100238.jpg' # I *know* xyz_001 exists in a filename
# Out:
# ls: cannot open directory '/content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data/person train images': Input/output error

# %%
train(epochs)

# %%
cv_heatmap_pred_batch,pose_estimate_cv_loss = cv_step(cv_image_batch,cv_gt_heatmaps_batch,cv_gt_validities_batch)

# %%
latest_checkpoint = tf.train.latest_checkpoint("/content/drive/MyDrive/pose_estimate_checkpoints")

# %%
latest_checkpoint
# Out:
# '/content/drive/MyDrive/pose_estimate_checkpoints/ckpt-12'

# %%
checkpoint.restore(latest_checkpoint)

# %%
cv_images = os.listdir("/content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data/person cv images")
cv_datagen = cv_generator(cv_images,cv_annotations,batch_size=cv_batch_size)

# %%
def plotting_data(test_img,heatmap,test_validity):

  test_img = test_img[0]

  mean=np.array([0.485, 0.456, 0.406])
  std=np.array([0.229, 0.224, 0.225])

  test_img = test_img*std + mean
  heatmap = np.sum(heatmap[0],axis=0)

  fig = plt.figure(2,figsize=(20,20))
  plt.gray()

  ax1 = fig.add_subplot(121)
  ax1.imshow(test_img)

  ax2 = fig.add_subplot(122)
  ax2.imshow(heatmap)
  
  plt.show()

# %%
cv_imgs_batch,cv_gt_heatmaps_batch,cv_gt_validities_batch = next(cv_datagen)
single_cv_img = cv_imgs_batch[0,:,:,:]
single_cv_img = single_cv_img.reshape(1,single_cv_img.shape[0],single_cv_img.shape[1],single_cv_img.shape[2])
single_cv_gt_heatmap = cv_gt_heatmaps_batch[0,:,:,:]
single_cv_gt_heatmap = single_cv_gt_heatmap.reshape(1,single_cv_gt_heatmap.shape[0],single_cv_gt_heatmap.shape[1],single_cv_gt_heatmap.shape[2])
single_cv_gt_validity = cv_gt_validities_batch[0,:,:,:]
single_cv_gt_validity = single_cv_gt_validity.reshape(1,single_cv_gt_validity.shape[0],single_cv_gt_validity.shape[1],single_cv_gt_validity.shape[2])

# %%
single_cv_img.shape
# Out:
# (1, 256, 192, 3)

# %%
single_cv_gt_heatmap.shape
# Out:
# (1, 17, 64, 48)

# %%
single_cv_gt_validity.shape
# Out:
# (1, 17, 1, 1)

# %%
pretrained_pose_resnet.trainable = True
cv_img_heatmap_pred = pretrained_pose_resnet(single_cv_img,training=False)

# %%
cv_img_heatmap_pred
# Out:
# <tf.Tensor: shape=(1, 17, 64, 48), dtype=float32, numpy=
# array([[[[-3.44450586e-04,  1.10005215e-03,  2.55681295e-03, ...,
#            2.72703357e-04,  1.25141349e-03,  1.78277399e-03],
#          [ 1.77311059e-03,  1.53625943e-03,  1.06256641e-03, ...,
#            1.28837489e-03,  1.33702904e-03,  8.01322050e-04],
#          [-3.96358781e-04, -1.27807539e-03, -8.48305412e-04, ...,
#           -4.41068783e-04, -3.79516743e-04, -7.69781880e-04],
#          ...,
#          [-2.57947296e-03, -1.63875893e-03, -8.59982334e-04, ...,
#           -7.93283805e-04, -5.15019521e-04, -1.95627753e-03],
#          [-3.19900550e-03, -3.40592023e-03, -2.76610162e-03, ...,
#           -1.29713025e-03, -2.40870658e-03, -2.20541749e-03],
#          [-1.68772228e-03, -1.92582048e-03, -2.29654368e-03, ...,
#            6.55988231e-04,  1.93686225e-04, -7.79314898e-04]],
#
#         [[-1.31133851e-03, -2.14779470e-03, -2.27574725e-03, ...,
#            1.42778177e-03,  1.70938764e-03,  1.22863613e-03],
#          [ 7.91201368e-04,  1.80242583e-04, -1.03921816e-03, ...,
#           -2.58927234e-04,  2.12803483e-04,  2.15722248e-04],
#          [-1.95018016e-04, -3.00356187e-04, -1.31046399e-04, ...,
#           -3.16821877e-03, -2.84797512e-03, -3.53856292e-03],
#          ...,
#          [-9.32995230e-04, -2.11690087e-03, -3.13657336e-03, ...,
#           -6.41364604e-04, -1.79928634e-03, -2.42734235e-03],
#          [-2.71649752e-03, -2.15742085e-03, -1.75252743e-03, ...,
#           -1.50423404e-03, -1.35639496e-03, -9.10408795e-04],
#          [-1.18112657e-03, -1.47348922e-03, -1.45395380e-03, ...,
#           -6.71217218e-04,  3.96532007e-04,  9.65542160e-04]],
#
#         [[ 9.42830928e-04,  8.04450363e-04,  1.14343688e-03, ...,
#           -4.94175218e-03, -3.63581907e-03, -1.86677743e-03],
#          [-1.92727894e-04,  6.16297126e-04,  8.94405879e-04, ...,
#           -1.53833255e-03, -1.17505901e-03,  2.26661842e-03],
#          [-2.66544521e-06, -1.94451865e-03, -1.22762937e-03, ...,
#            9.03219916e-04, -1.60344876e-04, -1.46829523e-04],
#          ...,
#          [-7.55144283e-05, -7.76865520e-04, -1.53753255e-03, ...,
#           -1.57610793e-03, -1.04929041e-03, -5.48874959e-05],
#          [ 8.10514204e-04,  1.29760429e-03,  9.41199251e-04, ...,
#           -2.69050058e-03, -1.76590588e-03, -2.49956734e-04],
#          [ 1.53329875e-03,  2.65373383e-03,  2.78062467e-03, ...,
#           -3.09808180e-04, -2.85685901e-03, -2.83804163e-03]],
#
#         ...,
#
#         [[-1.51931308e-03,  2.47644261e-04, -1.93091016e-03, ...,
#           -4.08012792e-03, -5.17878216e-03, -3.82023212e-03],
#          [-1.59815606e-03, -2.33794563e-04, -1.53937377e-04, ...,
#           -2.75770482e-03, -1.63028296e-03,  1.69968233e-04],
#          [ 1.12674013e-03,  7.51827843e-04, -1.02917384e-03, ...,
#            2.04197783e-03,  3.13094072e-03,  2.93679908e-03],
#          ...,
#          [-1.23717543e-03, -1.11952890e-03, -7.43687153e-04, ...,
#            2.20061000e-03,  2.25142296e-03,  1.32403336e-03],
#          [ 1.37994066e-04, -5.39855100e-04, -4.62902710e-04, ...,
#            2.33021565e-04, -1.06583815e-03, -1.90849137e-03],
#          [-1.82686839e-03, -8.51274468e-04,  1.97878107e-04, ...,
#           -3.71963717e-04, -2.06430070e-03, -2.65988335e-03]],
#
#         [[-2.69415136e-03, -1.68138277e-03, -2.37033702e-04, ...,
#            6.73547387e-04,  9.13919881e-04,  9.86156054e-04],
#          [ 1.49837788e-03,  2.08161771e-03,  2.55439430e-03, ...,
#           -2.03185715e-03, -1.01948436e-03, -9.52845439e-05],
#          [ 1.65142119e-04,  1.12786889e-04,  2.69140117e-04, ...,
#            7.55397603e-04,  1.56844035e-04, -1.32435001e-04],
#          ...,
#          [ 5.95498737e-03, -1.34986285e-02, -2.20588688e-02, ...,
#            8.90408233e-02,  3.91814224e-02,  2.69745756e-03],
#          [-1.79980136e-02, -1.71114467e-02, -1.01992795e-02, ...,
#            7.85108730e-02,  3.26738544e-02, -4.37332410e-03],
#          [-2.54182145e-02, -2.56402120e-02, -1.56239970e-02, ...,
#            2.17584856e-02,  7.19631743e-03, -3.67741287e-03]],
#
#         [[-8.60689022e-03, -7.12049287e-03, -3.61390319e-03, ...,
#            3.55163403e-03, -7.28403218e-04, -4.89978120e-04],
#          [-3.19379382e-04, -1.88003294e-04, -2.78539956e-05, ...,
#            1.54100265e-03,  1.88547280e-03,  1.36233680e-03],
#          [ 2.00273469e-04,  3.48101463e-03,  3.24186124e-03, ...,
#            6.99554477e-03,  4.83751763e-03,  3.83855123e-03],
#          ...,
#          [ 4.56380472e-03,  5.77175524e-03,  7.94548821e-03, ...,
#            2.42098328e-03,  1.05117634e-03, -4.47854400e-04],
#          [-9.66461375e-05,  1.23001356e-03,  2.49461643e-03, ...,
#           -4.60540224e-03, -3.82399745e-03, -3.52032017e-03],
#          [-2.67716497e-03, -1.11982413e-03,  2.95744278e-04, ...,
#            8.78761522e-04, -1.64417736e-03, -3.24937887e-03]]]],
#       dtype=float32)>

# %%
print("GROUNDTRUTH HEATMAP")
plotting_data(single_cv_img,single_cv_gt_heatmap,single_cv_gt_validity)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# GROUNDTRUTH HEATMAP

# %%
print("PREDICTED HEATMAP")
plotting_data(single_cv_img,cv_img_heatmap_pred.numpy(),single_cv_gt_validity)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# PREDICTED HEATMAP

# %%
train_images = os.listdir("/content/drive/MyDrive/Human Pose Estimation/Human Pose Estimation Data/person train images")
train_datagen = train_generator(train_images,training_annotations,batch_size=batch_size)

# %%
train_imgs_batch,train_gt_heatmaps_batch,train_gt_validities_batch = next(train_datagen)
single_train_img = train_imgs_batch[0,:,:,:]
single_train_img = single_train_img.reshape(1,single_train_img.shape[0],single_train_img.shape[1],
                                            single_train_img.shape[2])
single_train_gt_heatmap = train_gt_heatmaps_batch[0,:,:,:]
single_train_gt_heatmap = single_train_gt_heatmap.reshape(1,single_train_gt_heatmap.shape[0],
                                                          single_train_gt_heatmap.shape[1],
                                                          single_train_gt_heatmap.shape[2])
single_train_gt_validity = train_gt_validities_batch[0,:,:,:]
single_train_gt_validity = single_train_gt_validity.reshape(1,single_train_gt_validity.shape[0],
                                                            single_train_gt_validity.shape[1],
                                                            single_train_gt_validity.shape[2])

# %%
print("GROUNDTRUTH HEATMAP")
plotting_data(single_train_img,single_train_gt_heatmap,single_train_gt_validity)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# GROUNDTRUTH HEATMAP

# %%
pretrained_pose_resnet.trainable = True
train_img_heatmap_pred = pretrained_pose_resnet(single_train_img,training=False)

# %%
print("PREDICTED HEATMAP")
plotting_data(single_train_img,train_img_heatmap_pred.numpy(),single_train_gt_validity)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# PREDICTED HEATMAP
